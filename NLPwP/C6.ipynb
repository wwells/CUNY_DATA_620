# %%
import nltk

# %%
def gender_features(word):
    return {'last_letter': word[-1]}
gender_features('Shrek')
# Out:
# {'last_letter': 'k'}

# %%
from nltk.corpus import names
labeled_names = ([(name, 'male') for name in names.words('male.txt')] + [(name, 'female') for name in names.words('female.txt')])

# %%
import random
random.shuffle(labeled_names)

# %%
featuresets = [(gender_features(n), gender) for (n, gender) in labeled_names]
train_set, test_set = featuresets[500:], featuresets[:500]
classifier = nltk.NaiveBayesClassifier.train(train_set)

# %%
featuresets
# Out:
# [({'last_letter': u'a'}, 'female'),
#  ({'last_letter': u'o'}, 'female'),
#  ({'last_letter': u'l'}, 'female'),
#  ({'last_letter': u't'}, 'male'),
#  ({'last_letter': u'e'}, 'female'),
#  ({'last_letter': u'e'}, 'female'),
#  ({'last_letter': u'r'}, 'male'),
#  ({'last_letter': u'a'}, 'female'),
#  ({'last_letter': u'n'}, 'male'),
#  ({'last_letter': u'a'}, 'female'),
#  ({'last_letter': u'k'}, 'male'),
#  ({'last_letter': u'n'}, 'male'),
#  ({'last_letter': u'a'}, 'female'),
#  ({'last_letter': u'l'}, 'female'),
#  ({'last_letter': u'e'}, 'female'),
#  ({'last_letter': u'h'}, 'female'),
#  ({'last_letter': u'l'}, 'male'),
#  ({'last_letter': u'm'}, 'female'),
#  ({'last_letter': u't'}, 'male'),
#  ({'last_letter': u'a'}, 'female'),
#  ({'last_letter': u'a'}, 'female'),
#  ({'last_letter': u'n'}, 'female'),
#  ({'last_letter': u's'}, 'male'),
#  ({'last_letter': u'n'}, 'male'),
#  ({'last_letter': u't'}, 'female'),
#  ({'last_letter': u'd'}, 'male'),
#  ({'last_letter': u'y'}, 'male'),
#  ({'last_letter': u'd'}, 'male'),
#  ({'last_letter': u'n'}, 'male'),
#  ({'last_letter': u'i'}, 'female'),
#  ({'last_letter': u'l'}, 'female'),
#  ({'last_letter': u'n'}, 'male'),
#  ({'last_letter': u'e'}, 'female'),
#  ({'last_letter': u'e'}, 'male'),
#  ({'last_letter': u'a'}, 'female'),
#  ({'last_letter': u'e'}, 'male'),
#  ({'last_letter': u'e'}, 'male'),
#  ({'last_letter': u'y'}, 'female'),
#  ({'last_letter': u'a'}, 'female'),
#  ({'last_letter': u'e'}, 'female'),
#  ({'last_letter': u'e'}, 'female'),
#  ({'last_letter': u'a'}, 'female'),
#  ({'last_letter': u's'}, 'male'),
#  ({'last_letter': u'e'}, 'female'),
#  ({'last_letter': u'd'}, 'female'),
#  ({'last_letter': u'e'}, 'female'),
#  ({'last_letter': u's'}, 'female'),
#  ({'last_letter': u'g'}, 'female'),
#  ({'last_letter': u'e'}, 'female'),
#  ({'last_letter': u'e'}, 'male'),
#  ({'last_letter': u's'}, 'male'),
#  ({'last_letter': u'a'}, 'female'),
#  ({'last_letter': u'l'}, 'female'),
#  ({'last_letter': u'e'}, 'female'),
#  ({'last_letter': u'd'}, 'male'),
#  ({'last_letter': u'm'}, 'male'),
#  ({'last_letter': u'r'}, 'female'),
#  ({'last_letter': u'y'}, 'male'),
#  ({'last_letter': u'e'}, 'male'),
#  ({'last_letter': u'o'}, 'male'),
#  ({'last_letter': u'e'}, 'female'),
#  ({'last_letter': u's'}, 'female'),
#  ({'last_letter': u'h'}, 'female'),
#  ({'last_letter': u'a'}, 'female'),
#  ({'last_letter': u'n'}, 'male'),
#  ({'last_letter': u'e'}, 'female'),
#  ({'last_letter': u'v'}, 'male'),
#  ({'last_letter': u'd'}, 'male'),
#  ({'last_letter': u'n'}, 'male'),
#  ({'last_letter': u'n'}, 'female'),
#  ({'last_letter': u'e'}, 'female'),
#  ({'last_letter': u'i'}, 'female'),
#  ({'last_letter': u'l'}, 'female'),
#  ({'last_letter': u'e'}, 'female'),
#  ({'last_letter': u'e'}, 'female'),
#  ({'last_letter': u'n'}, 'male'),
#  ({'last_letter': u'e'}, 'male'),
#  ({'last_letter': u'n'}, 'male'),
#  ({'last_letter': u'e'}, 'male'),
#  ({'last_letter': u'e'}, 'male'),
#  ({'last_letter': u'd'}, 'male'),
#  ({'last_letter': u'a'}, 'female'),
#  ({'last_letter': u'i'}, 'female'),
#  ({'last_letter': u'n'}, 'female'),
#  ({'last_letter': u'i'}, 'female'),
#  ({'last_letter': u'n'}, 'male'),
#  ({'last_letter': u'b'}, 'male'),
#  ({'last_letter': u'e'}, 'female'),
#  ({'last_letter': u'd'}, 'male'),
#  ({'last_letter': u'e'}, 'female'),
#  ({'last_letter': u'a'}, 'female'),
#  ({'last_letter': u'r'}, 'male'),
#  ({'last_letter': u'l'}, 'male'),
#  ({'last_letter': u'e'}, 'male'),
#  ({'last_letter': u'a'}, 'female'),
#  ({'last_letter': u'e'}, 'male'),
#  ({'last_letter': u'e'}, 'female'),
#  ({'last_letter': u'a'}, 'female'),
#  ({'last_letter': u'a'}, 'female'),
#  ({'last_letter': u'l'}, 'male'),
#  ({'last_letter': u'e'}, 'male'),
#  ({'last_letter': u'e'}, 'female'),
#  ({'last_letter': u'l'}, 'male'),
#  ({'last_letter': u'y'}, 'male'),
#  ({'last_letter': u'a'}, 'female'),
#  ({'last_letter': u'e'}, 'female'),
#  ({'last_letter': u'a'}, 'female'),
#  ({'last_letter': u'a'}, 'female'),
#  ({'last_letter': u'e'}, 'male'),
#  ({'last_letter': u'n'}, 'female'),
#  ({'last_letter': u'a'}, 'female'),
#  ({'last_letter': u't'}, 'male'),
#  ({'last_letter': u'e'}, 'male'),
#  ({'last_letter': u'y'}, 'female'),
#  ({'last_letter': u'n'}, 'female'),
#  ({'last_letter': u'n'}, 'male'),
#  ({'last_letter': u'e'}, 'female'),
#  ({'last_letter': u't'}, 'male'),
#  ({'last_letter': u'a'}, 'female'),
#  ({'last_letter': u'a'}, 'female'),
#  ({'last_letter': u's'}, 'male'),
#  ({'last_letter': u'n'}, 'female'),
#  ({'last_letter': u'h'}, 'male'),
#  ({'last_letter': u's'}, 'male'),
#  ({'last_letter': u'a'}, 'female'),
#  ({'last_letter': u'a'}, 'female'),
#  ({'last_letter': u'a'}, 'female'),
#  ({'last_letter': u'n'}, 'female'),
#  ({'last_letter': u'y'}, 'male'),
#  ({'last_letter': u'd'}, 'male'),
#  ({'last_letter': u't'}, 'male'),
#  ({'last_letter': u'a'}, 'female'),
#  ({'last_letter': u'e'}, 'male'),
#  ({'last_letter': u'a'}, 'female'),
#  ({'last_letter': u'e'}, 'female'),
#  ({'last_letter': u'a'}, 'female'),
#  ({'last_letter': u'a'}, 'female'),
#  ({'last_letter': u'd'}, 'male'),
#  ({'last_letter': u'e'}, 'female'),
#  ({'last_letter': u'a'}, 'female'),
#  ({'last_letter': u's'}, 'male'),
#  ({'last_letter': u'y'}, 'male'),
#  ({'last_letter': u'i'}, 'female'),
#  ({'last_letter': u'n'}, 'female'),
#  ({'last_letter': u'e'}, 'female'),
#  ({'last_letter': u'e'}, 'female'),
#  ({'last_letter': u's'}, 'male'),
#  ({'last_letter': u'a'}, 'female'),
#  ({'last_letter': u'e'}, 'female'),
#  ({'last_letter': u'r'}, 'male'),
#  ({'last_letter': u'a'}, 'female'),
#  ({'last_letter': u'n'}, 'female'),
#  ({'last_letter': u'e'}, 'male'),
#  ({'last_letter': u'n'}, 'female'),
#  ({'last_letter': u'y'}, 'female'),
#  ({'last_letter': u'e'}, 'female'),
#  ({'last_letter': u'a'}, 'female'),
#  ({'last_letter': u's'}, 'male'),
#  ({'last_letter': u'e'}, 'female'),
#  ({'last_letter': u'e'}, 'male'),
#  ({'last_letter': u's'}, 'female'),
#  ({'last_letter': u'e'}, 'female'),
#  ({'last_letter': u'y'}, 'female'),
#  ({'last_letter': u'n'}, 'female'),
#  ({'last_letter': u'e'}, 'female'),
#  ({'last_letter': u'l'}, 'female'),
#  ({'last_letter': u'e'}, 'female'),
#  ({'last_letter': u'a'}, 'female'),
#  ({'last_letter': u'a'}, 'female'),
#  ({'last_letter': u'n'}, 'female'),
#  ({'last_letter': u'e'}, 'female'),
#  ({'last_letter': u'e'}, 'female'),
#  ({'last_letter': u'e'}, 'female'),
#  ({'last_letter': u'a'}, 'female'),
#  ({'last_letter': u'e'}, 'female'),
#  ({'last_letter': u'y'}, 'male'),
#  ({'last_letter': u'e'}, 'male'),
#  ({'last_letter': u'a'}, 'female'),
#  ({'last_letter': u'h'}, 'female'),
#  ({'last_letter': u'e'}, 'female'),
#  ({'last_letter': u'e'}, 'male'),
#  ({'last_letter': u'a'}, 'female'),
#  ({'last_letter': u'r'}, 'female'),
#  ({'last_letter': u'y'}, 'male'),
#  ({'last_letter': u'e'}, 'female'),
#  ({'last_letter': u'i'}, 'female'),
#  ({'last_letter': u'i'}, 'female'),
#  ({'last_letter': u'y'}, 'male'),
#  ({'last_letter': u'm'}, 'female'),
#  ({'last_letter': u'a'}, 'female'),
#  ({'last_letter': u'a'}, 'female'),
#  ({'last_letter': u'a'}, 'female'),
#  ({'last_letter': u'e'}, 'female'),
#  ({'last_letter': u'e'}, 'female'),
#  ({'last_letter': u'a'}, 'female'),
#  ({'last_letter': u'e'}, 'female'),
#  ({'last_letter': u'n'}, 'male'),
#  ({'last_letter': u'n'}, 'female'),
#  ({'last_letter': u'y'}, 'female'),
#  ({'last_letter': u'e'}, 'female'),
#  ({'last_letter': u'a'}, 'female'),
#  ({'last_letter': u'y'}, 'female'),
#  ({'last_letter': u'm'}, 'male'),
#  ({'last_letter': u'y'}, 'male'),
#  ({'last_letter': u'm'}, 'male'),
#  ({'last_letter': u'y'}, 'female'),
#  ({'last_letter': u'n'}, 'male'),
#  ({'last_letter': u'y'}, 'male'),
#  ({'last_letter': u'e'}, 'male'),
#  ({'last_letter': u'e'}, 'female'),
#  ({'last_letter': u'n'}, 'female'),
#  ({'last_letter': u'y'}, 'female'),
#  ({'last_letter': u'y'}, 'female'),
#  ({'last_letter': u'o'}, 'male'),
#  ({'last_letter': u'i'}, 'female'),
#  ({'last_letter': u'e'}, 'female'),
#  ({'last_letter': u's'}, 'female'),
#  ({'last_letter': u'a'}, 'female'),
#  ({'last_letter': u'a'}, 'female'),
#  ({'last_letter': u'a'}, 'female'),
#  ({'last_letter': u'y'}, 'female'),
#  ({'last_letter': u'd'}, 'male'),
#  ({'last_letter': u'e'}, 'female'),
#  ({'last_letter': u'e'}, 'male'),
#  ({'last_letter': u'u'}, 'male'),
#  ({'last_letter': u'e'}, 'female'),
#  ({'last_letter': u'l'}, 'female'),
#  ({'last_letter': u'a'}, 'female'),
#  ({'last_letter': u'y'}, 'female'),
#  ({'last_letter': u'r'}, 'male'),
#  ({'last_letter': u'e'}, 'female'),
#  ({'last_letter': u's'}, 'male'),
#  ({'last_letter': u'd'}, 'male'),
#  ({'last_letter': u's'}, 'male'),
#  ({'last_letter': u'a'}, 'female'),
#  ({'last_letter': u'e'}, 'female'),
#  ({'last_letter': u'e'}, 'male'),
#  ({'last_letter': u'n'}, 'female'),
#  ({'last_letter': u'y'}, 'female'),
#  ({'last_letter': u'a'}, 'female'),
#  ({'last_letter': u'd'}, 'male'),
#  ({'last_letter': u'e'}, 'female'),
#  ({'last_letter': u'a'}, 'female'),
#  ({'last_letter': u'n'}, 'female'),
#  ({'last_letter': u'a'}, 'female'),
#  ({'last_letter': u'a'}, 'female'),
#  ({'last_letter': u'e'}, 'female'),
#  ({'last_letter': u'y'}, 'female'),
#  ({'last_letter': u't'}, 'male'),
#  ({'last_letter': u'c'}, 'male'),
#  ({'last_letter': u'a'}, 'female'),
#  ({'last_letter': u'h'}, 'female'),
#  ({'last_letter': u'a'}, 'female'),
#  ({'last_letter': u'e'}, 'female'),
#  ({'last_letter': u'n'}, 'female'),
#  ({'last_letter': u'y'}, 'male'),
#  ({'last_letter': u'a'}, 'female'),
#  ({'last_letter': u'y'}, 'female'),
#  ({'last_letter': u'a'}, 'female'),
#  ({'last_letter': u'e'}, 'female'),
#  ({'last_letter': u'y'}, 'male'),
#  ({'last_letter': u'i'}, 'female'),
#  ({'last_letter': u'e'}, 'male'),
#  ({'last_letter': u'n'}, 'female'),
#  ({'last_letter': u'e'}, 'male'),
#  ({'last_letter': u'a'}, 'female'),
#  ({'last_letter': u'i'}, 'female'),
#  ({'last_letter': u'e'}, 'male'),
#  ({'last_letter': u'e'}, 'female'),
#  ({'last_letter': u'e'}, 'female'),
#  ({'last_letter': u'i'}, 'female'),
#  ({'last_letter': u'e'}, 'female'),
#  ({'last_letter': u'a'}, 'female'),
#  ({'last_letter': u'a'}, 'male'),
#  ({'last_letter': u'y'}, 'male'),
#  ({'last_letter': u'y'}, 'female'),
#  ({'last_letter': u'u'}, 'male'),
#  ({'last_letter': u'a'}, 'female'),
#  ({'last_letter': u'e'}, 'male'),
#  ({'last_letter': u'n'}, 'female'),
#  ({'last_letter': u'e'}, 'male'),
#  ({'last_letter': u't'}, 'male'),
#  ({'last_letter': u'a'}, 'female'),
#  ({'last_letter': u'e'}, 'male'),
#  ({'last_letter': u'm'}, 'female'),
#  ({'last_letter': u'a'}, 'female'),
#  ({'last_letter': u'k'}, 'male'),
#  ({'last_letter': u'x'}, 'male'),
#  ({'last_letter': u'y'}, 'female'),
#  ({'last_letter': u'a'}, 'female'),
#  ({'last_letter': u'e'}, 'female'),
#  ({'last_letter': u'a'}, 'female'),
#  ({'last_letter': u'i'}, 'female'),
#  ({'last_letter': u'a'}, 'female'),
#  ({'last_letter': u'a'}, 'female'),
#  ({'last_letter': u'y'}, 'female'),
#  ({'last_letter': u'a'}, 'female'),
#  ({'last_letter': u'a'}, 'female'),
#  ({'last_letter': u'e'}, 'female'),
#  ({'last_letter': u'i'}, 'female'),
#  ({'last_letter': u'e'}, 'female'),
#  ({'last_letter': u'n'}, 'female'),
#  ({'last_letter': u'y'}, 'male'),
#  ({'last_letter': u'i'}, 'female'),
#  ({'last_letter': u'y'}, 'female'),
#  ({'last_letter': u'n'}, 'male'),
#  ({'last_letter': u'i'}, 'female'),
#  ({'last_letter': u'm'}, 'male'),
#  ({'last_letter': u's'}, 'female'),
#  ({'last_letter': u'a'}, 'female'),
#  ({'last_letter': u'l'}, 'male'),
#  ({'last_letter': u'e'}, 'female'),
#  ({'last_letter': u'i'}, 'male'),
#  ({'last_letter': u'e'}, 'female'),
#  ({'last_letter': u's'}, 'male'),
#  ({'last_letter': u'e'}, 'female'),
#  ({'last_letter': u'y'}, 'male'),
#  ({'last_letter': u'h'}, 'male'),
#  ({'last_letter': u'a'}, 'female'),
#  ({'last_letter': u'e'}, 'male'),
#  ({'last_letter': u'a'}, 'female'),
#  ({'last_letter': u't'}, 'female'),
#  ({'last_letter': u'y'}, 'female'),
#  ({'last_letter': u'd'}, 'male'),
#  ({'last_letter': u'a'}, 'female'),
#  ({'last_letter': u'y'}, 'male'),
#  ({'last_letter': u'n'}, 'female'),
#  ({'last_letter': u'f'}, 'female'),
#  ({'last_letter': u'a'}, 'female'),
#  ({'last_letter': u'd'}, 'male'),
#  ({'last_letter': u'a'}, 'female'),
#  ({'last_letter': u'n'}, 'female'),
#  ({'last_letter': u'y'}, 'male'),
#  ({'last_letter': u'e'}, 'female'),
#  ({'last_letter': u'e'}, 'female'),
#  ({'last_letter': u'y'}, 'male'),
#  ({'last_letter': u'e'}, 'female'),
#  ({'last_letter': u'y'}, 'male'),
#  ({'last_letter': u'n'}, 'female'),
#  ({'last_letter': u'i'}, 'female'),
#  ({'last_letter': u'k'}, 'male'),
#  ({'last_letter': u'o'}, 'male'),
#  ({'last_letter': u'e'}, 'female'),
#  ({'last_letter': u'r'}, 'male'),
#  ({'last_letter': u'o'}, 'male'),
#  ({'last_letter': u'a'}, 'female'),
#  ({'last_letter': u'e'}, 'male'),
#  ({'last_letter': u'f'}, 'male'),
#  ({'last_letter': u'e'}, 'female'),
#  ({'last_letter': u'a'}, 'female'),
#  ({'last_letter': u'e'}, 'male'),
#  ({'last_letter': u'h'}, 'female'),
#  ({'last_letter': u'k'}, 'male'),
#  ({'last_letter': u'j'}, 'female'),
#  ({'last_letter': u's'}, 'male'),
#  ({'last_letter': u'y'}, 'female'),
#  ({'last_letter': u'e'}, 'female'),
#  ({'last_letter': u'a'}, 'female'),
#  ({'last_letter': u'e'}, 'male'),
#  ({'last_letter': u'e'}, 'female'),
#  ({'last_letter': u'r'}, 'male'),
#  ({'last_letter': u'a'}, 'female'),
#  ({'last_letter': u'g'}, 'male'),
#  ({'last_letter': u'y'}, 'female'),
#  ({'last_letter': u'a'}, 'female'),
#  ({'last_letter': u'r'}, 'male'),
#  ({'last_letter': u'a'}, 'female'),
#  ({'last_letter': u'n'}, 'male'),
#  ({'last_letter': u'i'}, 'male'),
#  ({'last_letter': u'e'}, 'female'),
#  ({'last_letter': u's'}, 'male'),
#  ({'last_letter': u'e'}, 'female'),
#  ({'last_letter': u'n'}, 'male'),
#  ({'last_letter': u'e'}, 'male'),
#  ({'last_letter': u'c'}, 'male'),
#  ({'last_letter': u'y'}, 'male'),
#  ({'last_letter': u'r'}, 'male'),
#  ({'last_letter': u'n'}, 'female'),
#  ({'last_letter': u'y'}, 'female'),
#  ({'last_letter': u'i'}, 'female'),
#  ({'last_letter': u'a'}, 'female'),
#  ({'last_letter': u'e'}, 'male'),
#  ({'last_letter': u'a'}, 'female'),
#  ({'last_letter': u'e'}, 'female'),
#  ({'last_letter': u'y'}, 'female'),
#  ({'last_letter': u'i'}, 'male'),
#  ({'last_letter': u'e'}, 'male'),
#  ({'last_letter': u'n'}, 'female'),
#  ({'last_letter': u'd'}, 'female'),
#  ({'last_letter': u'b'}, 'male'),
#  ({'last_letter': u'n'}, 'male'),
#  ({'last_letter': u'a'}, 'female'),
#  ({'last_letter': u'a'}, 'female'),
#  ({'last_letter': u'n'}, 'female'),
#  ({'last_letter': u'a'}, 'male'),
#  ({'last_letter': u'e'}, 'female'),
#  ({'last_letter': u's'}, 'male'),
#  ({'last_letter': u'e'}, 'female'),
#  ({'last_letter': u'e'}, 'male'),
#  ({'last_letter': u'n'}, 'male'),
#  ({'last_letter': u'y'}, 'female'),
#  ({'last_letter': u'y'}, 'male'),
#  ({'last_letter': u'e'}, 'female'),
#  ({'last_letter': u'a'}, 'female'),
#  ({'last_letter': u'e'}, 'female'),
#  ({'last_letter': u'n'}, 'male'),
#  ({'last_letter': u'a'}, 'female'),
#  ({'last_letter': u'e'}, 'female'),
#  ({'last_letter': u'a'}, 'female'),
#  ({'last_letter': u'a'}, 'female'),
#  ({'last_letter': u'h'}, 'male'),
#  ({'last_letter': u'l'}, 'female'),
#  ({'last_letter': u'e'}, 'female'),
#  ({'last_letter': u's'}, 'male'),
#  ({'last_letter': u'r'}, 'male'),
#  ({'last_letter': u'a'}, 'female'),
#  ({'last_letter': u's'}, 'female'),
#  ({'last_letter': u'e'}, 'female'),
#  ({'last_letter': u'a'}, 'female'),
#  ({'last_letter': u'y'}, 'male'),
#  ({'last_letter': u't'}, 'male'),
#  ({'last_letter': u'a'}, 'female'),
#  ({'last_letter': u'e'}, 'female'),
#  ({'last_letter': u'e'}, 'male'),
#  ({'last_letter': u'z'}, 'male'),
#  ({'last_letter': u'a'}, 'female'),
#  ({'last_letter': u'a'}, 'female'),
#  ({'last_letter': u'n'}, 'male'),
#  ({'last_letter': u't'}, 'female'),
#  ({'last_letter': u'y'}, 'female'),
#  ({'last_letter': u'w'}, 'male'),
#  ({'last_letter': u'y'}, 'male'),
#  ({'last_letter': u'n'}, 'female'),
#  ({'last_letter': u'a'}, 'female'),
#  ({'last_letter': u'a'}, 'female'),
#  ({'last_letter': u'y'}, 'male'),
#  ({'last_letter': u's'}, 'male'),
#  ({'last_letter': u'a'}, 'female'),
#  ({'last_letter': u'e'}, 'female'),
#  ({'last_letter': u'e'}, 'female'),
#  ({'last_letter': u'e'}, 'female'),
#  ({'last_letter': u'e'}, 'female'),
#  ({'last_letter': u'y'}, 'female'),
#  ({'last_letter': u'y'}, 'female'),
#  ({'last_letter': u'n'}, 'male'),
#  ({'last_letter': u'e'}, 'female'),
#  ({'last_letter': u'a'}, 'female'),
#  ({'last_letter': u'a'}, 'female'),
#  ({'last_letter': u'n'}, 'male'),
#  ({'last_letter': u'e'}, 'male'),
#  ({'last_letter': u'a'}, 'female'),
#  ({'last_letter': u'e'}, 'female'),
#  ({'last_letter': u'e'}, 'female'),
#  ({'last_letter': u'e'}, 'female'),
#  ({'last_letter': u'e'}, 'female'),
#  ({'last_letter': u'e'}, 'female'),
#  ({'last_letter': u'y'}, 'male'),
#  ({'last_letter': u'o'}, 'male'),
#  ({'last_letter': u'e'}, 'female'),
#  ({'last_letter': u'y'}, 'female'),
#  ({'last_letter': u'e'}, 'male'),
#  ({'last_letter': u'e'}, 'female'),
#  ({'last_letter': u'a'}, 'female'),
#  ({'last_letter': u'a'}, 'female'),
#  ({'last_letter': u'a'}, 'female'),
#  ({'last_letter': u's'}, 'male'),
#  ({'last_letter': u'r'}, 'male'),
#  ({'last_letter': u'a'}, 'female'),
#  ({'last_letter': u'e'}, 'female'),
#  ({'last_letter': u'y'}, 'male'),
#  ({'last_letter': u'a'}, 'female'),
#  ({'last_letter': u'o'}, 'male'),
#  ({'last_letter': u'y'}, 'male'),
#  ({'last_letter': u'a'}, 'female'),
#  ({'last_letter': u'y'}, 'male'),
#  ({'last_letter': u'a'}, 'female'),
#  ({'last_letter': u'a'}, 'female'),
#  ({'last_letter': u'o'}, 'male'),
#  ({'last_letter': u'y'}, 'male'),
#  ({'last_letter': u'e'}, 'male'),
#  ({'last_letter': u'a'}, 'female'),
#  ({'last_letter': u'i'}, 'female'),
#  ({'last_letter': u'i'}, 'female'),
#  ({'last_letter': u'y'}, 'female'),
#  ({'last_letter': u'e'}, 'female'),
#  ({'last_letter': u'n'}, 'male'),
#  ({'last_letter': u'o'}, 'male'),
#  ({'last_letter': u'a'}, 'female'),
#  ({'last_letter': u'e'}, 'female'),
#  ({'last_letter': u'r'}, 'male'),
#  ({'last_letter': u'y'}, 'male'),
#  ({'last_letter': u'n'}, 'male'),
#  ({'last_letter': u'i'}, 'female'),
#  ({'last_letter': u'y'}, 'male'),
#  ({'last_letter': u'n'}, 'male'),
#  ({'last_letter': u's'}, 'male'),
#  ({'last_letter': u'n'}, 'female'),
#  ({'last_letter': u'd'}, 'male'),
#  ({'last_letter': u'n'}, 'female'),
#  ({'last_letter': u'e'}, 'female'),
#  ({'last_letter': u'e'}, 'female'),
#  ({'last_letter': u'a'}, 'female'),
#  ({'last_letter': u'r'}, 'male'),
#  ({'last_letter': u'y'}, 'male'),
#  ({'last_letter': u'o'}, 'male'),
#  ({'last_letter': u'e'}, 'male'),
#  ({'last_letter': u'a'}, 'female'),
#  ({'last_letter': u'e'}, 'female'),
#  ({'last_letter': u'y'}, 'male'),
#  ({'last_letter': u'a'}, 'female'),
#  ({'last_letter': u'n'}, 'male'),
#  ({'last_letter': u'e'}, 'female'),
#  ({'last_letter': u'n'}, 'female'),
#  ({'last_letter': u'e'}, 'female'),
#  ({'last_letter': u'e'}, 'female'),
#  ({'last_letter': u'a'}, 'female'),
#  ({'last_letter': u'e'}, 'male'),
#  ({'last_letter': u'a'}, 'female'),
#  ({'last_letter': u'r'}, 'male'),
#  ({'last_letter': u'a'}, 'female'),
#  ({'last_letter': u'd'}, 'male'),
#  ({'last_letter': u'a'}, 'female'),
#  ({'last_letter': u'y'}, 'female'),
#  ({'last_letter': u'e'}, 'female'),
#  ({'last_letter': u'a'}, 'female'),
#  ({'last_letter': u'a'}, 'female'),
#  ({'last_letter': u'a'}, 'female'),
#  ({'last_letter': u'i'}, 'female'),
#  ({'last_letter': u'y'}, 'female'),
#  ({'last_letter': u'i'}, 'male'),
#  ({'last_letter': u'g'}, 'female'),
#  ({'last_letter': u'a'}, 'female'),
#  ({'last_letter': u'a'}, 'female'),
#  ({'last_letter': u'e'}, 'female'),
#  ({'last_letter': u'e'}, 'female'),
#  ({'last_letter': u'a'}, 'female'),
#  ({'last_letter': u'n'}, 'female'),
#  ({'last_letter': u'e'}, 'female'),
#  ({'last_letter': u'd'}, 'male'),
#  ({'last_letter': u's'}, 'male'),
#  ({'last_letter': u'i'}, 'female'),
#  ({'last_letter': u'i'}, 'female'),
#  ({'last_letter': u'x'}, 'male'),
#  ({'last_letter': u'm'}, 'male'),
#  ({'last_letter': u'y'}, 'female'),
#  ({'last_letter': u't'}, 'male'),
#  ({'last_letter': u'e'}, 'female'),
#  ({'last_letter': u'm'}, 'male'),
#  ({'last_letter': u'y'}, 'female'),
#  ({'last_letter': u'e'}, 'female'),
#  ({'last_letter': u'n'}, 'male'),
#  ({'last_letter': u'a'}, 'female'),
#  ({'last_letter': u'l'}, 'male'),
#  ({'last_letter': u'e'}, 'female'),
#  ({'last_letter': u'a'}, 'female'),
#  ({'last_letter': u'f'}, 'male'),
#  ({'last_letter': u's'}, 'male'),
#  ({'last_letter': u'e'}, 'male'),
#  ({'last_letter': u'a'}, 'female'),
#  ({'last_letter': u'n'}, 'male'),
#  ({'last_letter': u'e'}, 'female'),
#  ({'last_letter': u's'}, 'female'),
#  ({'last_letter': u'n'}, 'male'),
#  ({'last_letter': u'n'}, 'male'),
#  ({'last_letter': u'e'}, 'female'),
#  ({'last_letter': u'd'}, 'male'),
#  ({'last_letter': u'e'}, 'female'),
#  ({'last_letter': u'e'}, 'male'),
#  ({'last_letter': u'y'}, 'male'),
#  ({'last_letter': u't'}, 'male'),
#  ({'last_letter': u'a'}, 'female'),
#  ({'last_letter': u'e'}, 'female'),
#  ({'last_letter': u'n'}, 'female'),
#  ({'last_letter': u'n'}, 'male'),
#  ({'last_letter': u'r'}, 'male'),
#  ({'last_letter': u'e'}, 'male'),
#  ({'last_letter': u't'}, 'male'),
#  ({'last_letter': u'e'}, 'female'),
#  ({'last_letter': u'w'}, 'male'),
#  ({'last_letter': u'i'}, 'female'),
#  ({'last_letter': u'e'}, 'male'),
#  ({'last_letter': u's'}, 'male'),
#  ({'last_letter': u'e'}, 'female'),
#  ({'last_letter': u'g'}, 'male'),
#  ({'last_letter': u'a'}, 'female'),
#  ({'last_letter': u'e'}, 'female'),
#  ({'last_letter': u'a'}, 'female'),
#  ({'last_letter': u'e'}, 'male'),
#  ({'last_letter': u'o'}, 'male'),
#  ({'last_letter': u'e'}, 'female'),
#  ({'last_letter': u'a'}, 'female'),
#  ({'last_letter': u'l'}, 'female'),
#  ({'last_letter': u'e'}, 'male'),
#  ({'last_letter': u'l'}, 'female'),
#  ({'last_letter': u'e'}, 'female'),
#  ({'last_letter': u't'}, 'male'),
#  ({'last_letter': u'n'}, 'male'),
#  ({'last_letter': u'e'}, 'male'),
#  ({'last_letter': u'e'}, 'female'),
#  ({'last_letter': u'n'}, 'male'),
#  ({'last_letter': u'e'}, 'female'),
#  ({'last_letter': u'd'}, 'female'),
#  ({'last_letter': u'd'}, 'male'),
#  ({'last_letter': u'n'}, 'female'),
#  ({'last_letter': u'n'}, 'male'),
#  ({'last_letter': u'a'}, 'female'),
#  ({'last_letter': u'y'}, 'female'),
#  ({'last_letter': u'y'}, 'female'),
#  ({'last_letter': u'i'}, 'female'),
#  ({'last_letter': u'e'}, 'female'),
#  ({'last_letter': u'l'}, 'male'),
#  ({'last_letter': u'e'}, 'female'),
#  ({'last_letter': u'f'}, 'male'),
#  ({'last_letter': u'n'}, 'female'),
#  ({'last_letter': u'n'}, 'male'),
#  ({'last_letter': u'd'}, 'female'),
#  ({'last_letter': u'e'}, 'female'),
#  ({'last_letter': u'o'}, 'male'),
#  ({'last_letter': u'a'}, 'female'),
#  ({'last_letter': u'a'}, 'female'),
#  ({'last_letter': u'e'}, 'female'),
#  ({'last_letter': u't'}, 'female'),
#  ({'last_letter': u'e'}, 'female'),
#  ({'last_letter': u'y'}, 'female'),
#  ({'last_letter': u'n'}, 'male'),
#  ({'last_letter': u'h'}, 'male'),
#  ({'last_letter': u'h'}, 'male'),
#  ({'last_letter': u'i'}, 'female'),
#  ({'last_letter': u'l'}, 'male'),
#  ({'last_letter': u'e'}, 'male'),
#  ({'last_letter': u'a'}, 'female'),
#  ({'last_letter': u'e'}, 'female'),
#  ({'last_letter': u'a'}, 'female'),
#  ({'last_letter': u'y'}, 'female'),
#  ({'last_letter': u'a'}, 'female'),
#  ({'last_letter': u'e'}, 'female'),
#  ({'last_letter': u'a'}, 'female'),
#  ({'last_letter': u'a'}, 'female'),
#  ({'last_letter': u'r'}, 'male'),
#  ({'last_letter': u'l'}, 'male'),
#  ({'last_letter': u'e'}, 'female'),
#  ({'last_letter': u'e'}, 'female'),
#  ({'last_letter': u'a'}, 'female'),
#  ({'last_letter': u'e'}, 'female'),
#  ({'last_letter': u'e'}, 'female'),
#  ({'last_letter': u'a'}, 'female'),
#  ({'last_letter': u'l'}, 'male'),
#  ({'last_letter': u'a'}, 'female'),
#  ({'last_letter': u'e'}, 'female'),
#  ({'last_letter': u'e'}, 'female'),
#  ({'last_letter': u'y'}, 'female'),
#  ({'last_letter': u'e'}, 'female'),
#  ({'last_letter': u'e'}, 'female'),
#  ({'last_letter': u'e'}, 'female'),
#  ({'last_letter': u'o'}, 'male'),
#  ({'last_letter': u'y'}, 'female'),
#  ({'last_letter': u'a'}, 'female'),
#  ({'last_letter': u'a'}, 'female'),
#  ({'last_letter': u'a'}, 'female'),
#  ({'last_letter': u'a'}, 'female'),
#  ({'last_letter': u's'}, 'female'),
#  ({'last_letter': u'w'}, 'male'),
#  ({'last_letter': u'a'}, 'female'),
#  ({'last_letter': u'e'}, 'female'),
#  ({'last_letter': u'n'}, 'female'),
#  ({'last_letter': u'e'}, 'female'),
#  ({'last_letter': u'e'}, 'female'),
#  ({'last_letter': u'y'}, 'male'),
#  ({'last_letter': u'e'}, 'female'),
#  ({'last_letter': u'a'}, 'female'),
#  ({'last_letter': u'y'}, 'male'),
#  ({'last_letter': u'e'}, 'female'),
#  ({'last_letter': u'a'}, 'female'),
#  ({'last_letter': u'd'}, 'male'),
#  ({'last_letter': u'n'}, 'female'),
#  ({'last_letter': u'h'}, 'male'),
#  ({'last_letter': u'd'}, 'female'),
#  ({'last_letter': u'l'}, 'male'),
#  ({'last_letter': u's'}, 'male'),
#  ({'last_letter': u's'}, 'female'),
#  ({'last_letter': u'a'}, 'female'),
#  ({'last_letter': u'a'}, 'female'),
#  ({'last_letter': u'h'}, 'female'),
#  ({'last_letter': u'y'}, 'female'),
#  ({'last_letter': u'n'}, 'male'),
#  ({'last_letter': u'y'}, 'male'),
#  ({'last_letter': u'y'}, 'male'),
#  ({'last_letter': u'a'}, 'female'),
#  ({'last_letter': u'a'}, 'female'),
#  ({'last_letter': u'y'}, 'male'),
#  ({'last_letter': u'a'}, 'female'),
#  ({'last_letter': u'i'}, 'female'),
#  ({'last_letter': u'd'}, 'male'),
#  ({'last_letter': u'i'}, 'female'),
#  ({'last_letter': u'e'}, 'female'),
#  ({'last_letter': u'a'}, 'female'),
#  ({'last_letter': u'o'}, 'male'),
#  ({'last_letter': u'e'}, 'female'),
#  ({'last_letter': u'e'}, 'female'),
#  ({'last_letter': u'n'}, 'male'),
#  ({'last_letter': u'y'}, 'male'),
#  ({'last_letter': u'a'}, 'female'),
#  ({'last_letter': u'e'}, 'male'),
#  ({'last_letter': u'a'}, 'female'),
#  ({'last_letter': u'n'}, 'male'),
#  ({'last_letter': u'a'}, 'female'),
#  ({'last_letter': u'e'}, 'female'),
#  ({'last_letter': u's'}, 'male'),
#  ({'last_letter': u'k'}, 'male'),
#  ({'last_letter': u'e'}, 'male'),
#  ({'last_letter': u'e'}, 'female'),
#  ({'last_letter': u'y'}, 'female'),
#  ({'last_letter': u'a'}, 'female'),
#  ({'last_letter': u'a'}, 'female'),
#  ({'last_letter': u'a'}, 'female'),
#  ({'last_letter': u'e'}, 'male'),
#  ({'last_letter': u'y'}, 'female'),
#  ({'last_letter': u'e'}, 'male'),
#  ({'last_letter': u'r'}, 'male'),
#  ({'last_letter': u'e'}, 'female'),
#  ({'last_letter': u'n'}, 'female'),
#  ({'last_letter': u'd'}, 'male'),
#  ({'last_letter': u'a'}, 'female'),
#  ({'last_letter': u'a'}, 'female'),
#  ({'last_letter': u'a'}, 'female'),
#  ({'last_letter': u'a'}, 'female'),
#  ({'last_letter': u'y'}, 'male'),
#  ({'last_letter': u'a'}, 'female'),
#  ({'last_letter': u'a'}, 'female'),
#  ({'last_letter': u'v'}, 'female'),
#  ({'last_letter': u'd'}, 'male'),
#  ({'last_letter': u'e'}, 'female'),
#  ({'last_letter': u'n'}, 'female'),
#  ({'last_letter': u's'}, 'male'),
#  ({'last_letter': u'e'}, 'male'),
#  ({'last_letter': u'a'}, 'female'),
#  ({'last_letter': u'a'}, 'female'),
#  ({'last_letter': u's'}, 'female'),
#  ({'last_letter': u'l'}, 'male'),
#  ({'last_letter': u'e'}, 'male'),
#  ({'last_letter': u'a'}, 'female'),
#  ({'last_letter': u'k'}, 'male'),
#  ({'last_letter': u'a'}, 'female'),
#  ({'last_letter': u'y'}, 'male'),
#  ({'last_letter': u'd'}, 'male'),
#  ({'last_letter': u'e'}, 'female'),
#  ({'last_letter': u'e'}, 'female'),
#  ({'last_letter': u'e'}, 'male'),
#  ({'last_letter': u'a'}, 'female'),
#  ({'last_letter': u'e'}, 'female'),
#  ({'last_letter': u'e'}, 'female'),
#  ({'last_letter': u'e'}, 'female'),
#  ({'last_letter': u'i'}, 'female'),
#  ({'last_letter': u'd'}, 'male'),
#  ({'last_letter': u'a'}, 'female'),
#  ({'last_letter': u'e'}, 'female'),
#  ({'last_letter': u'a'}, 'female'),
#  ({'last_letter': u's'}, 'male'),
#  ({'last_letter': u'e'}, 'female'),
#  ({'last_letter': u'e'}, 'male'),
#  ({'last_letter': u'y'}, 'female'),
#  ({'last_letter': u'p'}, 'male'),
#  ({'last_letter': u'e'}, 'female'),
#  ({'last_letter': u'r'}, 'female'),
#  ({'last_letter': u'e'}, 'female'),
#  ({'last_letter': u'a'}, 'female'),
#  ({'last_letter': u'e'}, 'male'),
#  ({'last_letter': u'n'}, 'male'),
#  ({'last_letter': u'n'}, 'male'),
#  ({'last_letter': u'i'}, 'female'),
#  ({'last_letter': u'a'}, 'female'),
#  ({'last_letter': u'n'}, 'male'),
#  ({'last_letter': u'a'}, 'female'),
#  ({'last_letter': u'e'}, 'female'),
#  ({'last_letter': u'e'}, 'female'),
#  ({'last_letter': u'a'}, 'female'),
#  ({'last_letter': u'e'}, 'female'),
#  ({'last_letter': u'e'}, 'female'),
#  ({'last_letter': u'e'}, 'female'),
#  ({'last_letter': u's'}, 'female'),
#  ({'last_letter': u'e'}, 'female'),
#  ({'last_letter': u'a'}, 'female'),
#  ({'last_letter': u'y'}, 'male'),
#  ({'last_letter': u'y'}, 'female'),
#  ({'last_letter': u'a'}, 'female'),
#  ({'last_letter': u'e'}, 'female'),
#  ({'last_letter': u'f'}, 'male'),
#  ({'last_letter': u'a'}, 'female'),
#  ({'last_letter': u'y'}, 'male'),
#  ({'last_letter': u'y'}, 'male'),
#  ({'last_letter': u'e'}, 'female'),
#  ({'last_letter': u'a'}, 'female'),
#  ({'last_letter': u'w'}, 'female'),
#  ({'last_letter': u's'}, 'female'),
#  ({'last_letter': u'a'}, 'female'),
#  ({'last_letter': u'n'}, 'male'),
#  ({'last_letter': u'a'}, 'female'),
#  ({'last_letter': u'a'}, 'female'),
#  ({'last_letter': u'a'}, 'female'),
#  ({'last_letter': u'e'}, 'male'),
#  ({'last_letter': u'n'}, 'female'),
#  ({'last_letter': u'l'}, 'male'),
#  ({'last_letter': u'e'}, 'female'),
#  ({'last_letter': u'a'}, 'female'),
#  ({'last_letter': u'e'}, 'female'),
#  ({'last_letter': u'e'}, 'female'),
#  ({'last_letter': u'k'}, 'male'),
#  ({'last_letter': u'o'}, 'female'),
#  ({'last_letter': u'a'}, 'female'),
#  ({'last_letter': u'i'}, 'female'),
#  ({'last_letter': u'a'}, 'female'),
#  ({'last_letter': u'a'}, 'male'),
#  ({'last_letter': u'e'}, 'male'),
#  ({'last_letter': u'a'}, 'female'),
#  ({'last_letter': u'a'}, 'female'),
#  ({'last_letter': u'n'}, 'male'),
#  ({'last_letter': u'a'}, 'female'),
#  ({'last_letter': u'y'}, 'male'),
#  ({'last_letter': u'e'}, 'female'),
#  ({'last_letter': u'a'}, 'female'),
#  ({'last_letter': u'i'}, 'female'),
#  ({'last_letter': u'n'}, 'female'),
#  ({'last_letter': u'a'}, 'female'),
#  ({'last_letter': u'y'}, 'male'),
#  ({'last_letter': u'a'}, 'female'),
#  ({'last_letter': u'e'}, 'male'),
#  ({'last_letter': u'v'}, 'male'),
#  ({'last_letter': u'e'}, 'female'),
#  ({'last_letter': u'e'}, 'female'),
#  ({'last_letter': u'e'}, 'female'),
#  ({'last_letter': u'p'}, 'male'),
#  ({'last_letter': u'l'}, 'female'),
#  ({'last_letter': u'e'}, 'female'),
#  ({'last_letter': u'd'}, 'male'),
#  ({'last_letter': u'y'}, 'female'),
#  ({'last_letter': u'l'}, 'male'),
#  ({'last_letter': u'i'}, 'female'),
#  ({'last_letter': u'r'}, 'female'),
#  ({'last_letter': u't'}, 'female'),
#  ({'last_letter': u'e'}, 'female'),
#  ({'last_letter': u'a'}, 'female'),
#  ({'last_letter': u'a'}, 'male'),
#  ({'last_letter': u'd'}, 'male'),
#  ({'last_letter': u'n'}, 'female'),
#  ({'last_letter': u'n'}, 'male'),
#  ({'last_letter': u'e'}, 'female'),
#  ({'last_letter': u'm'}, 'male'),
#  ({'last_letter': u'n'}, 'female'),
#  ({'last_letter': u'a'}, 'female'),
#  ({'last_letter': u'n'}, 'female'),
#  ({'last_letter': u'e'}, 'female'),
#  ({'last_letter': u'n'}, 'female'),
#  ({'last_letter': u'e'}, 'female'),
#  ({'last_letter': u'n'}, 'male'),
#  ({'last_letter': u't'}, 'male'),
#  ({'last_letter': u'l'}, 'female'),
#  ({'last_letter': u'e'}, 'female'),
#  ({'last_letter': u'l'}, 'male'),
#  ({'last_letter': u'l'}, 'female'),
#  ({'last_letter': u'e'}, 'female'),
#  ({'last_letter': u'y'}, 'male'),
#  ({'last_letter': u'l'}, 'female'),
#  ({'last_letter': u'e'}, 'male'),
#  ({'last_letter': u'a'}, 'female'),
#  ({'last_letter': u'n'}, 'male'),
#  ({'last_letter': u'g'}, 'male'),
#  ({'last_letter': u't'}, 'male'),
#  ({'last_letter': u'n'}, 'male'),
#  ({'last_letter': u't'}, 'male'),
#  ({'last_letter': u'm'}, 'male'),
#  ({'last_letter': u'y'}, 'female'),
#  ({'last_letter': u'a'}, 'female'),
#  ({'last_letter': u'e'}, 'female'),
#  ({'last_letter': u'e'}, 'female'),
#  ({'last_letter': u'd'}, 'male'),
#  ({'last_letter': u'd'}, 'male'),
#  ({'last_letter': u'y'}, 'female'),
#  ({'last_letter': u'a'}, 'female'),
#  ({'last_letter': u'a'}, 'female'),
#  ({'last_letter': u'r'}, 'male'),
#  ({'last_letter': u'e'}, 'female'),
#  ({'last_letter': u'y'}, 'male'),
#  ({'last_letter': u'e'}, 'female'),
#  ({'last_letter': u'a'}, 'female'),
#  ({'last_letter': u'a'}, 'female'),
#  ({'last_letter': u'a'}, 'female'),
#  ({'last_letter': u'y'}, 'female'),
#  ({'last_letter': u'a'}, 'female'),
#  ({'last_letter': u'y'}, 'female'),
#  ({'last_letter': u'e'}, 'female'),
#  ({'last_letter': u'i'}, 'male'),
#  ({'last_letter': u'l'}, 'male'),
#  ({'last_letter': u'k'}, 'male'),
#  ({'last_letter': u'e'}, 'female'),
#  ({'last_letter': u'e'}, 'female'),
#  ({'last_letter': u'a'}, 'female'),
#  ({'last_letter': u'n'}, 'female'),
#  ({'last_letter': u'l'}, 'male'),
#  ({'last_letter': u't'}, 'male'),
#  ({'last_letter': u'n'}, 'male'),
#  ({'last_letter': u'e'}, 'female'),
#  ({'last_letter': u'n'}, 'male'),
#  ({'last_letter': u'd'}, 'male'),
#  ({'last_letter': u'e'}, 'female'),
#  ({'last_letter': u'm'}, 'male'),
#  ({'last_letter': u'a'}, 'female'),
#  ({'last_letter': u'a'}, 'female'),
#  ({'last_letter': u'd'}, 'male'),
#  ({'last_letter': u'a'}, 'female'),
#  ({'last_letter': u'e'}, 'male'),
#  ({'last_letter': u'a'}, 'female'),
#  ({'last_letter': u'y'}, 'male'),
#  ({'last_letter': u'r'}, 'male'),
#  ({'last_letter': u'a'}, 'female'),
#  ({'last_letter': u'e'}, 'female'),
#  ({'last_letter': u'n'}, 'female'),
#  ({'last_letter': u'a'}, 'female'),
#  ({'last_letter': u'e'}, 'female'),
#  ({'last_letter': u'n'}, 'male'),
#  ({'last_letter': u'e'}, 'female'),
#  ({'last_letter': u'r'}, 'male'),
#  ({'last_letter': u'e'}, 'female'),
#  ({'last_letter': u'a'}, 'female'),
#  ({'last_letter': u'e'}, 'female'),
#  ({'last_letter': u'n'}, 'female'),
#  ({'last_letter': u'a'}, 'female'),
#  ({'last_letter': u'k'}, 'male'),
#  ({'last_letter': u'e'}, 'female'),
#  ({'last_letter': u'e'}, 'female'),
#  ({'last_letter': u'i'}, 'female'),
#  ({'last_letter': u'l'}, 'female'),
#  ({'last_letter': u'x'}, 'male'),
#  ({'last_letter': u'y'}, 'male'),
#  ({'last_letter': u'l'}, 'male'),
#  ({'last_letter': u'a'}, 'female'),
#  ({'last_letter': u'a'}, 'female'),
#  ({'last_letter': u'a'}, 'female'),
#  ({'last_letter': u'h'}, 'male'),
#  ({'last_letter': u'e'}, 'male'),
#  ({'last_letter': u'a'}, 'female'),
#  ({'last_letter': u'a'}, 'female'),
#  ({'last_letter': u'a'}, 'female'),
#  ({'last_letter': u'o'}, 'female'),
#  ({'last_letter': u'y'}, 'female'),
#  ({'last_letter': u'e'}, 'female'),
#  ({'last_letter': u'n'}, 'male'),
#  ({'last_letter': u'y'}, 'female'),
#  ({'last_letter': u'e'}, 'female'),
#  ({'last_letter': u'a'}, 'female'),
#  ({'last_letter': u'e'}, 'male'),
#  ({'last_letter': u'e'}, 'male'),
#  ({'last_letter': u'e'}, 'female'),
#  ({'last_letter': u'y'}, 'male'),
#  ({'last_letter': u't'}, 'male'),
#  ({'last_letter': u'a'}, 'female'),
#  ({'last_letter': u'i'}, 'female'),
#  ({'last_letter': u'e'}, 'female'),
#  ({'last_letter': u'r'}, 'male'),
#  ({'last_letter': u'l'}, 'female'),
#  ({'last_letter': u'a'}, 'female'),
#  ({'last_letter': u'y'}, 'male'),
#  ({'last_letter': u'a'}, 'female'),
#  ({'last_letter': u'a'}, 'female'),
#  ({'last_letter': u'd'}, 'male'),
#  ({'last_letter': u'n'}, 'female'),
#  ({'last_letter': u'g'}, 'male'),
#  ({'last_letter': u'a'}, 'female'),
#  ({'last_letter': u'e'}, 'male'),
#  ({'last_letter': u'n'}, 'male'),
#  ({'last_letter': u'e'}, 'female'),
#  ({'last_letter': u'n'}, 'female'),
#  ({'last_letter': u'h'}, 'male'),
#  ({'last_letter': u'e'}, 'female'),
#  ({'last_letter': u'd'}, 'female'),
#  ({'last_letter': u'e'}, 'female'),
#  ({'last_letter': u'd'}, 'female'),
#  ({'last_letter': u'p'}, 'male'),
#  ({'last_letter': u'y'}, 'female'),
#  ({'last_letter': u'a'}, 'female'),
#  ({'last_letter': u'e'}, 'male'),
#  ({'last_letter': u'e'}, 'male'),
#  ({'last_letter': u'a'}, 'female'),
#  ({'last_letter': u'e'}, 'female'),
#  ({'last_letter': u'y'}, 'male'),
#  ({'last_letter': u'l'}, 'female'),
#  ({'last_letter': u'e'}, 'male'),
#  ({'last_letter': u'y'}, 'female'),
#  ({'last_letter': u'i'}, 'female'),
#  ({'last_letter': u'l'}, 'female'),
#  ({'last_letter': u'r'}, 'male'),
#  ({'last_letter': u'a'}, 'female'),
#  ({'last_letter': u'a'}, 'female'),
#  ({'last_letter': u'a'}, 'female'),
#  ({'last_letter': u'e'}, 'male'),
#  ({'last_letter': u'e'}, 'female'),
#  ({'last_letter': u'r'}, 'female'),
#  ({'last_letter': u'e'}, 'female'),
#  ({'last_letter': u'e'}, 'female'),
#  ({'last_letter': u'a'}, 'female'),
#  ({'last_letter': u't'}, 'female'),
#  ...]

# %%
print(nltk.classify.accuracy(classifier, test_set))
# Out:
# 0.728

# %%
classifier.show_most_informative_features(5)
# Out:
# Most Informative Features
#              last_letter = u'a'           female : male   =     35.7 : 1.0
#              last_letter = u'k'             male : female =     31.8 : 1.0
#              last_letter = u'f'             male : female =     27.7 : 1.0
#              last_letter = u'p'             male : female =     12.6 : 1.0
#              last_letter = u'm'             male : female =     10.8 : 1.0

# %%
def gender_features2(name):
    features = {}
    features["first_letter"] = name[0].lower()
    features["last_letter"] = name[-1].lower()
    for letter in 'abcdefghijklmnopqrstuvwxyz':
        features["count({})".format(letter)] = name.lower().count(letter)
        features["has({})".format(letter)] = (letter in name.lower())
    return features

# %%
gender_features2('John')
# Out:
# {'count(a)': 0,
#  'count(b)': 0,
#  'count(c)': 0,
#  'count(d)': 0,
#  'count(e)': 0,
#  'count(f)': 0,
#  'count(g)': 0,
#  'count(h)': 1,
#  'count(i)': 0,
#  'count(j)': 1,
#  'count(k)': 0,
#  'count(l)': 0,
#  'count(m)': 0,
#  'count(n)': 1,
#  'count(o)': 1,
#  'count(p)': 0,
#  'count(q)': 0,
#  'count(r)': 0,
#  'count(s)': 0,
#  'count(t)': 0,
#  'count(u)': 0,
#  'count(v)': 0,
#  'count(w)': 0,
#  'count(x)': 0,
#  'count(y)': 0,
#  'count(z)': 0,
#  'first_letter': 'j',
#  'has(a)': False,
#  'has(b)': False,
#  'has(c)': False,
#  'has(d)': False,
#  'has(e)': False,
#  'has(f)': False,
#  'has(g)': False,
#  'has(h)': True,
#  'has(i)': False,
#  'has(j)': True,
#  'has(k)': False,
#  'has(l)': False,
#  'has(m)': False,
#  'has(n)': True,
#  'has(o)': True,
#  'has(p)': False,
#  'has(q)': False,
#  'has(r)': False,
#  'has(s)': False,
#  'has(t)': False,
#  'has(u)': False,
#  'has(v)': False,
#  'has(w)': False,
#  'has(x)': False,
#  'has(y)': False,
#  'has(z)': False,
#  'last_letter': 'n'}

# %%
featuresets = [(gender_features2(n), gender) for (n, gender) in labeled_names]
train_set, test_set = featuresets[500:], featuresets[:500]
classifier = nltk.NaiveBayesClassifier.train(train_set)
print(nltk.classify.accuracy(classifier, test_set))
# Out:
# 0.786

# %%
train_names = labeled_names[1500:]
devtest_names = labeled_names[500:1500]
test_names = labeled_names[:500]

# %%
train_set = [(gender_features(n), gender) for (n, gender) in train_names]
devtest_set = [(gender_features(n), gender) for (n, gender) in devtest_names]
test_set = [(gender_features(n), gender) for (n, gender) in test_names]
classifier = nltk.NaiveBayesClassifier.train(train_set)
print(nltk.classify.accuracy(classifier, devtest_set))
# Out:
# 0.768

# %%
errors = []
for (name, tag) in devtest_names:
     guess = classifier.classify(gender_features(name))
     if guess != tag:
         errors.append( (tag, guess, name) )

# %%
for (tag, guess, name) in sorted(errors):
     print('correct={:<8} guess={:<8s} name={:<30}'.format(tag, guess, name))
# Out:
# correct=female   guess=male     name=Ag
# correct=female   guess=male     name=Aigneis
# correct=female   guess=male     name=Alison
# correct=female   guess=male     name=Alyson
# correct=female   guess=male     name=Anabel
# correct=female   guess=male     name=Arlyn
# correct=female   guess=male     name=Astrid
# correct=female   guess=male     name=Averil
# correct=female   guess=male     name=Beitris
# correct=female   guess=male     name=Bess
# correct=female   guess=male     name=Bliss
# correct=female   guess=male     name=Brett
# correct=female   guess=male     name=Brook
# correct=female   guess=male     name=Caroljean
# correct=female   guess=male     name=Cat
# correct=female   guess=male     name=Cathrin
# correct=female   guess=male     name=Chandal
# correct=female   guess=male     name=Charil
# correct=female   guess=male     name=Charlot
# correct=female   guess=male     name=Charmian
# correct=female   guess=male     name=Charo
# correct=female   guess=male     name=Chloris
# correct=female   guess=male     name=Chrystel
# correct=female   guess=male     name=Cinnamon
# correct=female   guess=male     name=Clem
# correct=female   guess=male     name=Clio
# correct=female   guess=male     name=Con
# correct=female   guess=male     name=Coralyn
# correct=female   guess=male     name=Darryl
# correct=female   guess=male     name=Daveen
# correct=female   guess=male     name=Drew
# correct=female   guess=male     name=Ealasaid
# correct=female   guess=male     name=Eleanor
# correct=female   guess=male     name=Elisabet
# correct=female   guess=male     name=Ellen
# correct=female   guess=male     name=Esther
# correct=female   guess=male     name=Ethelind
# correct=female   guess=male     name=Ethyl
# correct=female   guess=male     name=Evaleen
# correct=female   guess=male     name=Fanchon
# correct=female   guess=male     name=Farrand
# correct=female   guess=male     name=Gail
# correct=female   guess=male     name=Gayleen
# correct=female   guess=male     name=Gillian
# correct=female   guess=male     name=Glyn
# correct=female   guess=male     name=Gredel
# correct=female   guess=male     name=Grethel
# correct=female   guess=male     name=Gwenn
# correct=female   guess=male     name=Ines
# correct=female   guess=male     name=Iris
# correct=female   guess=male     name=Jacklyn
# correct=female   guess=male     name=Jaclyn
# correct=female   guess=male     name=Janel
# correct=female   guess=male     name=Jasmin
# correct=female   guess=male     name=Jill
# correct=female   guess=male     name=Joan
# correct=female   guess=male     name=Juliann
# correct=female   guess=male     name=Kass
# correct=female   guess=male     name=Kerrin
# correct=female   guess=male     name=Kevyn
# correct=female   guess=male     name=Kiersten
# correct=female   guess=male     name=Kimberlyn
# correct=female   guess=male     name=Kym
# correct=female   guess=male     name=Kyrstin
# correct=female   guess=male     name=Laureen
# correct=female   guess=male     name=Leanor
# correct=female   guess=male     name=Leland
# correct=female   guess=male     name=Mairead
# correct=female   guess=male     name=Margo
# correct=female   guess=male     name=Marian
# correct=female   guess=male     name=Marie-Ann
# correct=female   guess=male     name=Maris
# correct=female   guess=male     name=Maryellen
# correct=female   guess=male     name=Maryjo
# correct=female   guess=male     name=Mavis
# correct=female   guess=male     name=Meaghan
# correct=female   guess=male     name=Megen
# correct=female   guess=male     name=Meghan
# correct=female   guess=male     name=Mildrid
# correct=female   guess=male     name=Milissent
# correct=female   guess=male     name=Moll
# correct=female   guess=male     name=Morgen
# correct=female   guess=male     name=Noell
# correct=female   guess=male     name=Pat
# correct=female   guess=male     name=Phylis
# correct=female   guess=male     name=Phylys
# correct=female   guess=male     name=Piper
# correct=female   guess=male     name=Rachael
# correct=female   guess=male     name=Rahal
# correct=female   guess=male     name=Rayshell
# correct=female   guess=male     name=Renell
# correct=female   guess=male     name=Robinet
# correct=female   guess=male     name=Ros
# correct=female   guess=male     name=Sean
# correct=female   guess=male     name=Sharl
# correct=female   guess=male     name=Sharyl
# correct=female   guess=male     name=Sheryl
# correct=female   guess=male     name=Siobhan
# correct=female   guess=male     name=Sybyl
# correct=female   guess=male     name=Teriann
# correct=female   guess=male     name=Thomasin
# correct=female   guess=male     name=Tim
# correct=female   guess=male     name=Van
# correct=female   guess=male     name=Viv
# correct=female   guess=male     name=Willow
# correct=male     guess=female   name=Abbey
# correct=male     guess=female   name=Adolph
# correct=male     guess=female   name=Alex
# correct=male     guess=female   name=Alfie
# correct=male     guess=female   name=Anatole
# correct=male     guess=female   name=Anatoly
# correct=male     guess=female   name=Andre
# correct=male     guess=female   name=Andrey
# correct=male     guess=female   name=Anthony
# correct=male     guess=female   name=Antony
# correct=male     guess=female   name=Ari
# correct=male     guess=female   name=Arie
# correct=male     guess=female   name=Aubrey
# correct=male     guess=female   name=Bailie
# correct=male     guess=female   name=Baily
# correct=male     guess=female   name=Benjie
# correct=male     guess=female   name=Benny
# correct=male     guess=female   name=Boyce
# correct=male     guess=female   name=Bradley
# correct=male     guess=female   name=Brice
# correct=male     guess=female   name=Broddie
# correct=male     guess=female   name=Carleigh
# correct=male     guess=female   name=Carlyle
# correct=male     guess=female   name=Chance
# correct=male     guess=female   name=Charlie
# correct=male     guess=female   name=Chaunce
# correct=male     guess=female   name=Constantine
# correct=male     guess=female   name=Corrie
# correct=male     guess=female   name=Cory
# correct=male     guess=female   name=Dimitri
# correct=male     guess=female   name=Donnie
# correct=male     guess=female   name=Dougie
# correct=male     guess=female   name=Dudley
# correct=male     guess=female   name=Eddy
# correct=male     guess=female   name=Elisha
# correct=male     guess=female   name=Ernie
# correct=male     guess=female   name=Ezra
# correct=male     guess=female   name=Franky
# correct=male     guess=female   name=Freddy
# correct=male     guess=female   name=French
# correct=male     guess=female   name=Friedrich
# correct=male     guess=female   name=Garth
# correct=male     guess=female   name=Gay
# correct=male     guess=female   name=Georgie
# correct=male     guess=female   name=Georgy
# correct=male     guess=female   name=Germaine
# correct=male     guess=female   name=Gerry
# correct=male     guess=female   name=Giavani
# correct=male     guess=female   name=Graeme
# correct=male     guess=female   name=Gregory
# correct=male     guess=female   name=Henrique
# correct=male     guess=female   name=Henry
# correct=male     guess=female   name=Herbie
# correct=male     guess=female   name=Horace
# correct=male     guess=female   name=Hurley
# correct=male     guess=female   name=Hy
# correct=male     guess=female   name=Irvine
# correct=male     guess=female   name=Jeffry
# correct=male     guess=female   name=Jessee
# correct=male     guess=female   name=Jodie
# correct=male     guess=female   name=Johny
# correct=male     guess=female   name=Judah
# correct=male     guess=female   name=Judy
# correct=male     guess=female   name=Jule
# correct=male     guess=female   name=Kelly
# correct=male     guess=female   name=Kennedy
# correct=male     guess=female   name=Lay
# correct=male     guess=female   name=Levi
# correct=male     guess=female   name=Louie
# correct=male     guess=female   name=Maurice
# correct=male     guess=female   name=Max
# correct=male     guess=female   name=Maxie
# correct=male     guess=female   name=Michale
# correct=male     guess=female   name=Mike
# correct=male     guess=female   name=Monte
# correct=male     guess=female   name=Morley
# correct=male     guess=female   name=Morly
# correct=male     guess=female   name=Murdoch
# correct=male     guess=female   name=Neddie
# correct=male     guess=female   name=Neddy
# correct=male     guess=female   name=Normie
# correct=male     guess=female   name=Obadiah
# correct=male     guess=female   name=Odie
# correct=male     guess=female   name=Osborne
# correct=male     guess=female   name=Pace
# correct=male     guess=female   name=Parke
# correct=male     guess=female   name=Patsy
# correct=male     guess=female   name=Quigly
# correct=male     guess=female   name=Ramsay
# correct=male     guess=female   name=Randie
# correct=male     guess=female   name=Ravi
# correct=male     guess=female   name=Reece
# correct=male     guess=female   name=Reube
# correct=male     guess=female   name=Roice
# correct=male     guess=female   name=Rolph
# correct=male     guess=female   name=Ronnie
# correct=male     guess=female   name=Rory
# correct=male     guess=female   name=Rube
# correct=male     guess=female   name=Ruby
# correct=male     guess=female   name=Rudie
# correct=male     guess=female   name=Rudy
# correct=male     guess=female   name=Salvatore
# correct=male     guess=female   name=Sayre
# correct=male     guess=female   name=See
# correct=male     guess=female   name=Selby
# correct=male     guess=female   name=Shelley
# correct=male     guess=female   name=Sidnee
# correct=male     guess=female   name=Sly
# correct=male     guess=female   name=Stevy
# correct=male     guess=female   name=Tanney
# correct=male     guess=female   name=Thorndike
# correct=male     guess=female   name=Torrey
# correct=male     guess=female   name=Townie
# correct=male     guess=female   name=Trace
# correct=male     guess=female   name=Tremayne
# correct=male     guess=female   name=Tully
# correct=male     guess=female   name=Tyrone
# correct=male     guess=female   name=Verge
# correct=male     guess=female   name=Welbie
# correct=male     guess=female   name=Welby
# correct=male     guess=female   name=Welsh
# correct=male     guess=female   name=Whitby
# correct=male     guess=female   name=Willi
# correct=male     guess=female   name=Woodie
# correct=male     guess=female   name=Woody
# correct=male     guess=female   name=Zane
# correct=male     guess=female   name=Zebadiah

# %%
def gender_features(word):
     return {'suffix1': word[-1:],
             'suffix2': word[-2:]}

# %%
train_set = [(gender_features(n), gender) for (n, gender) in train_names]
devtest_set = [(gender_features(n), gender) for (n, gender) in devtest_names]
classifier = nltk.NaiveBayesClassifier.train(train_set)
print(nltk.classify.accuracy(classifier, devtest_set))
# Out:
# 0.777

# %%
train_set
# Out:
# [({'suffix1': u'n', 'suffix2': u'in'}, 'female'),
#  ({'suffix1': u'e', 'suffix2': u'ie'}, 'female'),
#  ({'suffix1': u'n', 'suffix2': u'in'}, 'female'),
#  ({'suffix1': u'e', 'suffix2': u'te'}, 'female'),
#  ({'suffix1': u'e', 'suffix2': u'ie'}, 'male'),
#  ({'suffix1': u's', 'suffix2': u'ns'}, 'female'),
#  ({'suffix1': u'e', 'suffix2': u'ie'}, 'female'),
#  ({'suffix1': u'e', 'suffix2': u'ie'}, 'female'),
#  ({'suffix1': u'y', 'suffix2': u'ey'}, 'female'),
#  ({'suffix1': u'y', 'suffix2': u'oy'}, 'male'),
#  ({'suffix1': u'p', 'suffix2': u'ip'}, 'male'),
#  ({'suffix1': u'n', 'suffix2': u'in'}, 'female'),
#  ({'suffix1': u'e', 'suffix2': u'ne'}, 'female'),
#  ({'suffix1': u'a', 'suffix2': u'na'}, 'female'),
#  ({'suffix1': u'e', 'suffix2': u'ie'}, 'female'),
#  ({'suffix1': u'l', 'suffix2': u'el'}, 'male'),
#  ({'suffix1': u'e', 'suffix2': u'le'}, 'female'),
#  ({'suffix1': u'a', 'suffix2': u'na'}, 'female'),
#  ({'suffix1': u'e', 'suffix2': u'ie'}, 'female'),
#  ({'suffix1': u'e', 'suffix2': u'ye'}, 'female'),
#  ({'suffix1': u'a', 'suffix2': u'ia'}, 'female'),
#  ({'suffix1': u'n', 'suffix2': u'in'}, 'female'),
#  ({'suffix1': u't', 'suffix2': u'ot'}, 'male'),
#  ({'suffix1': u'e', 'suffix2': u'ne'}, 'female'),
#  ({'suffix1': u'n', 'suffix2': u'an'}, 'male'),
#  ({'suffix1': u'e', 'suffix2': u'te'}, 'female'),
#  ({'suffix1': u'o', 'suffix2': u'ro'}, 'male'),
#  ({'suffix1': u'e', 'suffix2': u'ie'}, 'female'),
#  ({'suffix1': u'y', 'suffix2': u'by'}, 'male'),
#  ({'suffix1': u'e', 'suffix2': u'ne'}, 'male'),
#  ({'suffix1': u'a', 'suffix2': u'ca'}, 'female'),
#  ({'suffix1': u'a', 'suffix2': u'la'}, 'female'),
#  ({'suffix1': u'o', 'suffix2': u'Jo'}, 'male'),
#  ({'suffix1': u'm', 'suffix2': u'am'}, 'male'),
#  ({'suffix1': u'e', 'suffix2': u'ce'}, 'male'),
#  ({'suffix1': u'n', 'suffix2': u'en'}, 'female'),
#  ({'suffix1': u'y', 'suffix2': u'ly'}, 'male'),
#  ({'suffix1': u'e', 'suffix2': u're'}, 'female'),
#  ({'suffix1': u'e', 'suffix2': u're'}, 'female'),
#  ({'suffix1': u'n', 'suffix2': u'in'}, 'female'),
#  ({'suffix1': u't', 'suffix2': u'tt'}, 'female'),
#  ({'suffix1': u'l', 'suffix2': u'yl'}, 'female'),
#  ({'suffix1': u'a', 'suffix2': u'ta'}, 'female'),
#  ({'suffix1': u'a', 'suffix2': u'ta'}, 'female'),
#  ({'suffix1': u'n', 'suffix2': u'nn'}, 'female'),
#  ({'suffix1': u's', 'suffix2': u'as'}, 'male'),
#  ({'suffix1': u'i', 'suffix2': u'di'}, 'female'),
#  ({'suffix1': u'i', 'suffix2': u'ri'}, 'female'),
#  ({'suffix1': u's', 'suffix2': u'as'}, 'female'),
#  ({'suffix1': u'l', 'suffix2': u'el'}, 'female'),
#  ({'suffix1': u'h', 'suffix2': u'ah'}, 'male'),
#  ({'suffix1': u'l', 'suffix2': u'il'}, 'male'),
#  ({'suffix1': u'e', 'suffix2': u'ee'}, 'female'),
#  ({'suffix1': u'e', 'suffix2': u'ne'}, 'female'),
#  ({'suffix1': u'n', 'suffix2': u'en'}, 'male'),
#  ({'suffix1': u'y', 'suffix2': u'ly'}, 'female'),
#  ({'suffix1': u'l', 'suffix2': u'al'}, 'male'),
#  ({'suffix1': u'a', 'suffix2': u'la'}, 'female'),
#  ({'suffix1': u'y', 'suffix2': u'ny'}, 'female'),
#  ({'suffix1': u'e', 'suffix2': u'le'}, 'female'),
#  ({'suffix1': u'e', 'suffix2': u'ne'}, 'male'),
#  ({'suffix1': u'e', 'suffix2': u'ie'}, 'female'),
#  ({'suffix1': u'r', 'suffix2': u'er'}, 'male'),
#  ({'suffix1': u'a', 'suffix2': u'da'}, 'female'),
#  ({'suffix1': u'r', 'suffix2': u'er'}, 'male'),
#  ({'suffix1': u'r', 'suffix2': u'er'}, 'male'),
#  ({'suffix1': u'x', 'suffix2': u'ax'}, 'male'),
#  ({'suffix1': u'h', 'suffix2': u'ah'}, 'female'),
#  ({'suffix1': u'a', 'suffix2': u'la'}, 'female'),
#  ({'suffix1': u'a', 'suffix2': u'na'}, 'female'),
#  ({'suffix1': u't', 'suffix2': u'tt'}, 'male'),
#  ({'suffix1': u'e', 'suffix2': u'ie'}, 'female'),
#  ({'suffix1': u'n', 'suffix2': u'nn'}, 'female'),
#  ({'suffix1': u's', 'suffix2': u'us'}, 'male'),
#  ({'suffix1': u's', 'suffix2': u'es'}, 'male'),
#  ({'suffix1': u'n', 'suffix2': u'en'}, 'male'),
#  ({'suffix1': u'a', 'suffix2': u'ra'}, 'female'),
#  ({'suffix1': u'd', 'suffix2': u'id'}, 'male'),
#  ({'suffix1': u'i', 'suffix2': u'mi'}, 'female'),
#  ({'suffix1': u's', 'suffix2': u'as'}, 'male'),
#  ({'suffix1': u'e', 'suffix2': u'te'}, 'male'),
#  ({'suffix1': u'n', 'suffix2': u'in'}, 'female'),
#  ({'suffix1': u'h', 'suffix2': u'ch'}, 'male'),
#  ({'suffix1': u'e', 'suffix2': u'ie'}, 'female'),
#  ({'suffix1': u'n', 'suffix2': u'en'}, 'female'),
#  ({'suffix1': u'e', 'suffix2': u'ce'}, 'female'),
#  ({'suffix1': u'i', 'suffix2': u'li'}, 'female'),
#  ({'suffix1': u'i', 'suffix2': u'ki'}, 'male'),
#  ({'suffix1': u'h', 'suffix2': u'ch'}, 'female'),
#  ({'suffix1': u'e', 'suffix2': u'ie'}, 'female'),
#  ({'suffix1': u'd', 'suffix2': u'rd'}, 'male'),
#  ({'suffix1': u'a', 'suffix2': u'na'}, 'female'),
#  ({'suffix1': u'e', 'suffix2': u'ie'}, 'male'),
#  ({'suffix1': u'a', 'suffix2': u'la'}, 'female'),
#  ({'suffix1': u'y', 'suffix2': u'ey'}, 'female'),
#  ({'suffix1': u'e', 'suffix2': u'te'}, 'female'),
#  ({'suffix1': u's', 'suffix2': u'us'}, 'male'),
#  ({'suffix1': u'd', 'suffix2': u'nd'}, 'male'),
#  ({'suffix1': u'n', 'suffix2': u'in'}, 'female'),
#  ({'suffix1': u'a', 'suffix2': u'la'}, 'female'),
#  ({'suffix1': u'i', 'suffix2': u'bi'}, 'female'),
#  ({'suffix1': u'a', 'suffix2': u'za'}, 'female'),
#  ({'suffix1': u'n', 'suffix2': u'yn'}, 'female'),
#  ({'suffix1': u'r', 'suffix2': u'er'}, 'male'),
#  ({'suffix1': u'a', 'suffix2': u'la'}, 'female'),
#  ({'suffix1': u'e', 'suffix2': u'ce'}, 'female'),
#  ({'suffix1': u'n', 'suffix2': u'in'}, 'male'),
#  ({'suffix1': u'e', 'suffix2': u'te'}, 'male'),
#  ({'suffix1': u'g', 'suffix2': u'ig'}, 'female'),
#  ({'suffix1': u's', 'suffix2': u'es'}, 'male'),
#  ({'suffix1': u'n', 'suffix2': u'an'}, 'female'),
#  ({'suffix1': u'e', 'suffix2': u'le'}, 'female'),
#  ({'suffix1': u'a', 'suffix2': u'la'}, 'female'),
#  ({'suffix1': u'a', 'suffix2': u'ia'}, 'female'),
#  ({'suffix1': u'a', 'suffix2': u'ha'}, 'female'),
#  ({'suffix1': u'a', 'suffix2': u'ia'}, 'male'),
#  ({'suffix1': u'e', 'suffix2': u'ee'}, 'female'),
#  ({'suffix1': u'a', 'suffix2': u'ia'}, 'female'),
#  ({'suffix1': u'n', 'suffix2': u'en'}, 'female'),
#  ({'suffix1': u'n', 'suffix2': u'yn'}, 'female'),
#  ({'suffix1': u's', 'suffix2': u'ns'}, 'male'),
#  ({'suffix1': u'e', 'suffix2': u'ce'}, 'male'),
#  ({'suffix1': u'e', 'suffix2': u'le'}, 'female'),
#  ({'suffix1': u'e', 'suffix2': u'se'}, 'female'),
#  ({'suffix1': u'l', 'suffix2': u'll'}, 'female'),
#  ({'suffix1': u'n', 'suffix2': u'in'}, 'male'),
#  ({'suffix1': u'n', 'suffix2': u'in'}, 'male'),
#  ({'suffix1': u'e', 'suffix2': u'ie'}, 'female'),
#  ({'suffix1': u'h', 'suffix2': u'gh'}, 'male'),
#  ({'suffix1': u'a', 'suffix2': u'na'}, 'female'),
#  ({'suffix1': u'i', 'suffix2': u'Di'}, 'female'),
#  ({'suffix1': u'm', 'suffix2': u'am'}, 'male'),
#  ({'suffix1': u'n', 'suffix2': u'en'}, 'male'),
#  ({'suffix1': u'n', 'suffix2': u'in'}, 'male'),
#  ({'suffix1': u'i', 'suffix2': u'ni'}, 'female'),
#  ({'suffix1': u'h', 'suffix2': u'ah'}, 'female'),
#  ({'suffix1': u'n', 'suffix2': u'yn'}, 'male'),
#  ({'suffix1': u'e', 'suffix2': u'ne'}, 'female'),
#  ({'suffix1': u'n', 'suffix2': u'en'}, 'female'),
#  ({'suffix1': u'e', 'suffix2': u'ne'}, 'female'),
#  ({'suffix1': u's', 'suffix2': u'is'}, 'male'),
#  ({'suffix1': u'n', 'suffix2': u'yn'}, 'female'),
#  ({'suffix1': u'e', 'suffix2': u'le'}, 'female'),
#  ({'suffix1': u'l', 'suffix2': u'il'}, 'male'),
#  ({'suffix1': u'e', 'suffix2': u'ie'}, 'male'),
#  ({'suffix1': u'y', 'suffix2': u'ry'}, 'female'),
#  ({'suffix1': u'e', 'suffix2': u'be'}, 'male'),
#  ({'suffix1': u's', 'suffix2': u'is'}, 'female'),
#  ({'suffix1': u'e', 'suffix2': u'ie'}, 'female'),
#  ({'suffix1': u'i', 'suffix2': u'di'}, 'female'),
#  ({'suffix1': u'e', 'suffix2': u'ie'}, 'male'),
#  ({'suffix1': u'a', 'suffix2': u'la'}, 'female'),
#  ({'suffix1': u'b', 'suffix2': u'ab'}, 'female'),
#  ({'suffix1': u's', 'suffix2': u'rs'}, 'male'),
#  ({'suffix1': u'n', 'suffix2': u'on'}, 'male'),
#  ({'suffix1': u'y', 'suffix2': u'ey'}, 'female'),
#  ({'suffix1': u'e', 'suffix2': u'ne'}, 'female'),
#  ({'suffix1': u'a', 'suffix2': u'va'}, 'female'),
#  ({'suffix1': u'e', 'suffix2': u'ie'}, 'male'),
#  ({'suffix1': u'e', 'suffix2': u'ce'}, 'female'),
#  ({'suffix1': u'h', 'suffix2': u'ah'}, 'male'),
#  ({'suffix1': u'l', 'suffix2': u'il'}, 'male'),
#  ({'suffix1': u'y', 'suffix2': u'ry'}, 'female'),
#  ({'suffix1': u'y', 'suffix2': u'ey'}, 'female'),
#  ({'suffix1': u'e', 'suffix2': u'te'}, 'female'),
#  ({'suffix1': u'y', 'suffix2': u'ty'}, 'female'),
#  ({'suffix1': u'y', 'suffix2': u'ry'}, 'male'),
#  ({'suffix1': u'c', 'suffix2': u'ic'}, 'male'),
#  ({'suffix1': u'a', 'suffix2': u'ia'}, 'female'),
#  ({'suffix1': u'm', 'suffix2': u'om'}, 'male'),
#  ({'suffix1': u'n', 'suffix2': u'en'}, 'male'),
#  ({'suffix1': u'a', 'suffix2': u'na'}, 'female'),
#  ({'suffix1': u'e', 'suffix2': u'le'}, 'female'),
#  ({'suffix1': u'a', 'suffix2': u'ta'}, 'female'),
#  ({'suffix1': u'a', 'suffix2': u'ea'}, 'female'),
#  ({'suffix1': u'e', 'suffix2': u'ne'}, 'female'),
#  ({'suffix1': u'e', 'suffix2': u're'}, 'male'),
#  ({'suffix1': u'e', 'suffix2': u'ee'}, 'female'),
#  ({'suffix1': u'e', 'suffix2': u'le'}, 'female'),
#  ({'suffix1': u'h', 'suffix2': u'th'}, 'female'),
#  ({'suffix1': u's', 'suffix2': u'is'}, 'female'),
#  ({'suffix1': u'n', 'suffix2': u'on'}, 'male'),
#  ({'suffix1': u'o', 'suffix2': u'ro'}, 'male'),
#  ({'suffix1': u'y', 'suffix2': u'ey'}, 'female'),
#  ({'suffix1': u'a', 'suffix2': u'na'}, 'female'),
#  ({'suffix1': u'i', 'suffix2': u'di'}, 'female'),
#  ({'suffix1': u'h', 'suffix2': u'th'}, 'male'),
#  ({'suffix1': u'a', 'suffix2': u'ta'}, 'female'),
#  ({'suffix1': u'e', 'suffix2': u'ne'}, 'female'),
#  ({'suffix1': u'a', 'suffix2': u'ia'}, 'female'),
#  ({'suffix1': u'n', 'suffix2': u'yn'}, 'female'),
#  ({'suffix1': u'e', 'suffix2': u'ie'}, 'male'),
#  ({'suffix1': u't', 'suffix2': u'tt'}, 'male'),
#  ({'suffix1': u'd', 'suffix2': u'nd'}, 'female'),
#  ({'suffix1': u'a', 'suffix2': u'la'}, 'female'),
#  ({'suffix1': u'a', 'suffix2': u'ca'}, 'female'),
#  ({'suffix1': u's', 'suffix2': u'is'}, 'female'),
#  ({'suffix1': u't', 'suffix2': u'nt'}, 'male'),
#  ({'suffix1': u'n', 'suffix2': u'on'}, 'male'),
#  ({'suffix1': u'a', 'suffix2': u'na'}, 'female'),
#  ({'suffix1': u'a', 'suffix2': u'La'}, 'female'),
#  ({'suffix1': u'e', 'suffix2': u'ie'}, 'female'),
#  ({'suffix1': u'y', 'suffix2': u'dy'}, 'male'),
#  ({'suffix1': u'e', 'suffix2': u'ie'}, 'female'),
#  ({'suffix1': u'a', 'suffix2': u'ta'}, 'female'),
#  ({'suffix1': u's', 'suffix2': u'is'}, 'male'),
#  ({'suffix1': u'e', 'suffix2': u'le'}, 'female'),
#  ({'suffix1': u'i', 'suffix2': u'di'}, 'female'),
#  ({'suffix1': u'e', 'suffix2': u'ie'}, 'female'),
#  ({'suffix1': u'd', 'suffix2': u'ld'}, 'male'),
#  ({'suffix1': u'a', 'suffix2': u'ea'}, 'female'),
#  ({'suffix1': u'e', 'suffix2': u'ie'}, 'female'),
#  ({'suffix1': u't', 'suffix2': u'at'}, 'female'),
#  ({'suffix1': u'a', 'suffix2': u'ia'}, 'female'),
#  ({'suffix1': u'o', 'suffix2': u'lo'}, 'male'),
#  ({'suffix1': u'a', 'suffix2': u'ta'}, 'female'),
#  ({'suffix1': u'a', 'suffix2': u'ka'}, 'female'),
#  ({'suffix1': u's', 'suffix2': u'us'}, 'male'),
#  ({'suffix1': u'g', 'suffix2': u'ig'}, 'female'),
#  ({'suffix1': u'a', 'suffix2': u'la'}, 'female'),
#  ({'suffix1': u'a', 'suffix2': u'na'}, 'female'),
#  ({'suffix1': u't', 'suffix2': u'tt'}, 'male'),
#  ({'suffix1': u'e', 'suffix2': u'ne'}, 'female'),
#  ({'suffix1': u'e', 'suffix2': u'le'}, 'female'),
#  ({'suffix1': u'a', 'suffix2': u'na'}, 'female'),
#  ({'suffix1': u'i', 'suffix2': u'si'}, 'female'),
#  ({'suffix1': u'e', 'suffix2': u'ce'}, 'male'),
#  ({'suffix1': u's', 'suffix2': u'us'}, 'male'),
#  ({'suffix1': u's', 'suffix2': u'ns'}, 'male'),
#  ({'suffix1': u'n', 'suffix2': u'an'}, 'female'),
#  ({'suffix1': u'l', 'suffix2': u'el'}, 'female'),
#  ({'suffix1': u'y', 'suffix2': u'dy'}, 'male'),
#  ({'suffix1': u'a', 'suffix2': u'na'}, 'female'),
#  ({'suffix1': u'h', 'suffix2': u'th'}, 'female'),
#  ({'suffix1': u'a', 'suffix2': u'la'}, 'female'),
#  ({'suffix1': u'r', 'suffix2': u'er'}, 'male'),
#  ({'suffix1': u'e', 'suffix2': u'te'}, 'female'),
#  ({'suffix1': u'l', 'suffix2': u'al'}, 'female'),
#  ({'suffix1': u'a', 'suffix2': u'la'}, 'female'),
#  ({'suffix1': u'a', 'suffix2': u'ra'}, 'female'),
#  ({'suffix1': u'n', 'suffix2': u'on'}, 'female'),
#  ({'suffix1': u's', 'suffix2': u'os'}, 'male'),
#  ({'suffix1': u'y', 'suffix2': u'ty'}, 'female'),
#  ({'suffix1': u'd', 'suffix2': u'rd'}, 'male'),
#  ({'suffix1': u'n', 'suffix2': u'on'}, 'male'),
#  ({'suffix1': u'n', 'suffix2': u'nn'}, 'female'),
#  ({'suffix1': u'e', 'suffix2': u'ne'}, 'female'),
#  ({'suffix1': u't', 'suffix2': u'et'}, 'male'),
#  ({'suffix1': u'y', 'suffix2': u'ky'}, 'female'),
#  ({'suffix1': u'e', 'suffix2': u'ne'}, 'female'),
#  ({'suffix1': u'e', 'suffix2': u'te'}, 'female'),
#  ({'suffix1': u'y', 'suffix2': u'dy'}, 'female'),
#  ({'suffix1': u'y', 'suffix2': u'ey'}, 'female'),
#  ({'suffix1': u'e', 'suffix2': u'ie'}, 'male'),
#  ({'suffix1': u'a', 'suffix2': u'ia'}, 'female'),
#  ({'suffix1': u'e', 'suffix2': u're'}, 'male'),
#  ({'suffix1': u'u', 'suffix2': u'ru'}, 'female'),
#  ({'suffix1': u'a', 'suffix2': u'ia'}, 'female'),
#  ({'suffix1': u'r', 'suffix2': u'ir'}, 'male'),
#  ({'suffix1': u'e', 'suffix2': u'ne'}, 'female'),
#  ({'suffix1': u'y', 'suffix2': u'dy'}, 'female'),
#  ({'suffix1': u'a', 'suffix2': u'ta'}, 'female'),
#  ({'suffix1': u'd', 'suffix2': u'rd'}, 'male'),
#  ({'suffix1': u'e', 'suffix2': u'he'}, 'male'),
#  ({'suffix1': u'r', 'suffix2': u'er'}, 'male'),
#  ({'suffix1': u'n', 'suffix2': u'an'}, 'male'),
#  ({'suffix1': u'a', 'suffix2': u'ia'}, 'female'),
#  ({'suffix1': u'o', 'suffix2': u'io'}, 'male'),
#  ({'suffix1': u'a', 'suffix2': u'da'}, 'female'),
#  ({'suffix1': u'n', 'suffix2': u'an'}, 'female'),
#  ({'suffix1': u'e', 'suffix2': u'fe'}, 'male'),
#  ({'suffix1': u'e', 'suffix2': u'ne'}, 'male'),
#  ({'suffix1': u'k', 'suffix2': u'ak'}, 'male'),
#  ({'suffix1': u'a', 'suffix2': u'na'}, 'female'),
#  ({'suffix1': u'i', 'suffix2': u'ri'}, 'female'),
#  ({'suffix1': u'a', 'suffix2': u'ia'}, 'female'),
#  ({'suffix1': u'y', 'suffix2': u'my'}, 'female'),
#  ({'suffix1': u'n', 'suffix2': u'on'}, 'male'),
#  ({'suffix1': u'a', 'suffix2': u'ta'}, 'female'),
#  ({'suffix1': u'l', 'suffix2': u'al'}, 'male'),
#  ({'suffix1': u'f', 'suffix2': u'ff'}, 'female'),
#  ({'suffix1': u'a', 'suffix2': u'ma'}, 'female'),
#  ({'suffix1': u'r', 'suffix2': u'er'}, 'male'),
#  ({'suffix1': u'l', 'suffix2': u'al'}, 'female'),
#  ({'suffix1': u'e', 'suffix2': u'ie'}, 'female'),
#  ({'suffix1': u'a', 'suffix2': u'ma'}, 'female'),
#  ({'suffix1': u'n', 'suffix2': u'an'}, 'male'),
#  ({'suffix1': u'l', 'suffix2': u'll'}, 'male'),
#  ({'suffix1': u'm', 'suffix2': u'im'}, 'male'),
#  ({'suffix1': u't', 'suffix2': u'tt'}, 'female'),
#  ({'suffix1': u'l', 'suffix2': u'el'}, 'male'),
#  ({'suffix1': u'n', 'suffix2': u'in'}, 'male'),
#  ({'suffix1': u'a', 'suffix2': u'da'}, 'female'),
#  ({'suffix1': u'a', 'suffix2': u'ka'}, 'female'),
#  ({'suffix1': u'a', 'suffix2': u'na'}, 'female'),
#  ({'suffix1': u'e', 'suffix2': u'le'}, 'female'),
#  ({'suffix1': u'l', 'suffix2': u'll'}, 'male'),
#  ({'suffix1': u's', 'suffix2': u'us'}, 'male'),
#  ({'suffix1': u'h', 'suffix2': u'th'}, 'female'),
#  ({'suffix1': u's', 'suffix2': u'es'}, 'male'),
#  ({'suffix1': u'e', 'suffix2': u'ne'}, 'female'),
#  ({'suffix1': u'a', 'suffix2': u'da'}, 'female'),
#  ({'suffix1': u'e', 'suffix2': u'le'}, 'male'),
#  ({'suffix1': u'e', 'suffix2': u'ie'}, 'female'),
#  ({'suffix1': u'n', 'suffix2': u'on'}, 'male'),
#  ({'suffix1': u'l', 'suffix2': u'il'}, 'female'),
#  ({'suffix1': u'e', 'suffix2': u'ie'}, 'female'),
#  ({'suffix1': u'e', 'suffix2': u'ie'}, 'female'),
#  ({'suffix1': u'i', 'suffix2': u'ri'}, 'female'),
#  ({'suffix1': u'r', 'suffix2': u'er'}, 'male'),
#  ({'suffix1': u'i', 'suffix2': u'ri'}, 'female'),
#  ({'suffix1': u'z', 'suffix2': u'iz'}, 'female'),
#  ({'suffix1': u'a', 'suffix2': u'ia'}, 'female'),
#  ({'suffix1': u'y', 'suffix2': u'ry'}, 'female'),
#  ({'suffix1': u'e', 'suffix2': u'ne'}, 'female'),
#  ({'suffix1': u'a', 'suffix2': u'ka'}, 'female'),
#  ({'suffix1': u'w', 'suffix2': u'ew'}, 'male'),
#  ({'suffix1': u'n', 'suffix2': u'on'}, 'female'),
#  ({'suffix1': u'e', 'suffix2': u'de'}, 'female'),
#  ({'suffix1': u'e', 'suffix2': u'ie'}, 'female'),
#  ({'suffix1': u'n', 'suffix2': u'en'}, 'female'),
#  ({'suffix1': u't', 'suffix2': u'rt'}, 'female'),
#  ({'suffix1': u'y', 'suffix2': u'by'}, 'female'),
#  ({'suffix1': u'e', 'suffix2': u'ie'}, 'female'),
#  ({'suffix1': u'y', 'suffix2': u'ky'}, 'female'),
#  ({'suffix1': u'a', 'suffix2': u'na'}, 'female'),
#  ({'suffix1': u'y', 'suffix2': u'cy'}, 'male'),
#  ({'suffix1': u'a', 'suffix2': u'ma'}, 'female'),
#  ({'suffix1': u'e', 'suffix2': u'le'}, 'female'),
#  ({'suffix1': u'o', 'suffix2': u'io'}, 'male'),
#  ({'suffix1': u'e', 'suffix2': u'ue'}, 'male'),
#  ({'suffix1': u'a', 'suffix2': u'ta'}, 'female'),
#  ({'suffix1': u'a', 'suffix2': u'ra'}, 'female'),
#  ({'suffix1': u'a', 'suffix2': u'ta'}, 'female'),
#  ({'suffix1': u'a', 'suffix2': u'ka'}, 'female'),
#  ({'suffix1': u'e', 'suffix2': u'ne'}, 'female'),
#  ({'suffix1': u'y', 'suffix2': u'ey'}, 'female'),
#  ({'suffix1': u'a', 'suffix2': u'na'}, 'female'),
#  ({'suffix1': u'e', 'suffix2': u'ce'}, 'male'),
#  ({'suffix1': u'a', 'suffix2': u'ta'}, 'female'),
#  ({'suffix1': u'e', 'suffix2': u'ie'}, 'male'),
#  ({'suffix1': u'y', 'suffix2': u'ny'}, 'female'),
#  ({'suffix1': u'e', 'suffix2': u'he'}, 'female'),
#  ({'suffix1': u'a', 'suffix2': u'va'}, 'female'),
#  ({'suffix1': u't', 'suffix2': u'et'}, 'male'),
#  ({'suffix1': u'n', 'suffix2': u'in'}, 'female'),
#  ({'suffix1': u'e', 'suffix2': u'ye'}, 'female'),
#  ({'suffix1': u'e', 'suffix2': u'oe'}, 'female'),
#  ({'suffix1': u'm', 'suffix2': u'im'}, 'male'),
#  ({'suffix1': u'l', 'suffix2': u'el'}, 'female'),
#  ({'suffix1': u'a', 'suffix2': u'sa'}, 'female'),
#  ({'suffix1': u'e', 'suffix2': u'ne'}, 'female'),
#  ({'suffix1': u'd', 'suffix2': u'ld'}, 'male'),
#  ({'suffix1': u'n', 'suffix2': u'yn'}, 'female'),
#  ({'suffix1': u'l', 'suffix2': u'ol'}, 'male'),
#  ({'suffix1': u'd', 'suffix2': u'ud'}, 'male'),
#  ({'suffix1': u'n', 'suffix2': u'nn'}, 'female'),
#  ({'suffix1': u'e', 'suffix2': u'ne'}, 'female'),
#  ({'suffix1': u'r', 'suffix2': u'er'}, 'male'),
#  ({'suffix1': u'd', 'suffix2': u'ed'}, 'male'),
#  ({'suffix1': u'e', 'suffix2': u'le'}, 'male'),
#  ({'suffix1': u'e', 'suffix2': u'ie'}, 'female'),
#  ({'suffix1': u'n', 'suffix2': u'on'}, 'male'),
#  ({'suffix1': u'e', 'suffix2': u'ie'}, 'female'),
#  ({'suffix1': u'y', 'suffix2': u'ly'}, 'female'),
#  ({'suffix1': u'h', 'suffix2': u'sh'}, 'male'),
#  ({'suffix1': u'a', 'suffix2': u'ia'}, 'female'),
#  ({'suffix1': u'n', 'suffix2': u'on'}, 'male'),
#  ({'suffix1': u'y', 'suffix2': u'dy'}, 'female'),
#  ({'suffix1': u'y', 'suffix2': u'cy'}, 'male'),
#  ({'suffix1': u'n', 'suffix2': u'en'}, 'female'),
#  ({'suffix1': u'e', 'suffix2': u'ie'}, 'female'),
#  ({'suffix1': u'l', 'suffix2': u'el'}, 'female'),
#  ({'suffix1': u'e', 'suffix2': u'ne'}, 'male'),
#  ({'suffix1': u'i', 'suffix2': u'di'}, 'female'),
#  ({'suffix1': u'a', 'suffix2': u'la'}, 'female'),
#  ({'suffix1': u'e', 'suffix2': u'ie'}, 'female'),
#  ({'suffix1': u'y', 'suffix2': u'zy'}, 'male'),
#  ({'suffix1': u'a', 'suffix2': u'ka'}, 'female'),
#  ({'suffix1': u'a', 'suffix2': u'sa'}, 'female'),
#  ({'suffix1': u'n', 'suffix2': u'on'}, 'male'),
#  ({'suffix1': u'e', 'suffix2': u'ie'}, 'female'),
#  ({'suffix1': u'y', 'suffix2': u'ay'}, 'male'),
#  ({'suffix1': u'e', 'suffix2': u'ee'}, 'male'),
#  ({'suffix1': u'k', 'suffix2': u'rk'}, 'female'),
#  ({'suffix1': u'e', 'suffix2': u'le'}, 'male'),
#  ({'suffix1': u'y', 'suffix2': u'dy'}, 'female'),
#  ({'suffix1': u'e', 'suffix2': u'le'}, 'female'),
#  ({'suffix1': u'n', 'suffix2': u'in'}, 'female'),
#  ({'suffix1': u't', 'suffix2': u'it'}, 'male'),
#  ({'suffix1': u'a', 'suffix2': u'la'}, 'female'),
#  ({'suffix1': u'e', 'suffix2': u'te'}, 'female'),
#  ({'suffix1': u'e', 'suffix2': u'ie'}, 'female'),
#  ({'suffix1': u'n', 'suffix2': u'in'}, 'male'),
#  ({'suffix1': u'a', 'suffix2': u'ia'}, 'female'),
#  ({'suffix1': u'y', 'suffix2': u'ly'}, 'male'),
#  ({'suffix1': u'e', 'suffix2': u'te'}, 'female'),
#  ({'suffix1': u'a', 'suffix2': u'sa'}, 'female'),
#  ({'suffix1': u'h', 'suffix2': u'ph'}, 'male'),
#  ({'suffix1': u't', 'suffix2': u'et'}, 'male'),
#  ({'suffix1': u'e', 'suffix2': u'ne'}, 'female'),
#  ({'suffix1': u'x', 'suffix2': u'ax'}, 'female'),
#  ({'suffix1': u'n', 'suffix2': u'nn'}, 'female'),
#  ({'suffix1': u'k', 'suffix2': u'ck'}, 'male'),
#  ({'suffix1': u'y', 'suffix2': u'ey'}, 'female'),
#  ({'suffix1': u'y', 'suffix2': u'ly'}, 'female'),
#  ({'suffix1': u'a', 'suffix2': u'na'}, 'female'),
#  ({'suffix1': u'l', 'suffix2': u'el'}, 'male'),
#  ({'suffix1': u'n', 'suffix2': u'en'}, 'female'),
#  ({'suffix1': u'l', 'suffix2': u'ol'}, 'male'),
#  ({'suffix1': u'e', 'suffix2': u'ne'}, 'female'),
#  ({'suffix1': u'y', 'suffix2': u'ry'}, 'female'),
#  ({'suffix1': u'o', 'suffix2': u'ko'}, 'female'),
#  ({'suffix1': u'h', 'suffix2': u'gh'}, 'male'),
#  ({'suffix1': u'n', 'suffix2': u'in'}, 'male'),
#  ({'suffix1': u'n', 'suffix2': u'en'}, 'female'),
#  ({'suffix1': u'n', 'suffix2': u'on'}, 'male'),
#  ({'suffix1': u'l', 'suffix2': u'il'}, 'male'),
#  ({'suffix1': u'l', 'suffix2': u'el'}, 'male'),
#  ({'suffix1': u'a', 'suffix2': u'na'}, 'female'),
#  ({'suffix1': u'a', 'suffix2': u'pa'}, 'female'),
#  ({'suffix1': u'e', 'suffix2': u'le'}, 'female'),
#  ({'suffix1': u'i', 'suffix2': u'di'}, 'female'),
#  ({'suffix1': u'r', 'suffix2': u'or'}, 'male'),
#  ({'suffix1': u'y', 'suffix2': u'ny'}, 'male'),
#  ({'suffix1': u'a', 'suffix2': u'da'}, 'female'),
#  ({'suffix1': u'i', 'suffix2': u'ki'}, 'female'),
#  ({'suffix1': u'a', 'suffix2': u'na'}, 'female'),
#  ({'suffix1': u'd', 'suffix2': u'nd'}, 'female'),
#  ({'suffix1': u'a', 'suffix2': u'sa'}, 'female'),
#  ({'suffix1': u'a', 'suffix2': u'ia'}, 'female'),
#  ({'suffix1': u'e', 'suffix2': u'le'}, 'male'),
#  ({'suffix1': u'e', 'suffix2': u'ie'}, 'female'),
#  ({'suffix1': u'a', 'suffix2': u'na'}, 'female'),
#  ({'suffix1': u'l', 'suffix2': u'il'}, 'female'),
#  ({'suffix1': u'e', 'suffix2': u'ie'}, 'female'),
#  ({'suffix1': u'e', 'suffix2': u'ne'}, 'female'),
#  ({'suffix1': u'y', 'suffix2': u'ey'}, 'male'),
#  ({'suffix1': u'l', 'suffix2': u'il'}, 'male'),
#  ({'suffix1': u'n', 'suffix2': u'nn'}, 'female'),
#  ({'suffix1': u'a', 'suffix2': u'da'}, 'female'),
#  ({'suffix1': u'i', 'suffix2': u'li'}, 'male'),
#  ({'suffix1': u'a', 'suffix2': u'ia'}, 'female'),
#  ({'suffix1': u'f', 'suffix2': u'af'}, 'male'),
#  ({'suffix1': u'l', 'suffix2': u'al'}, 'male'),
#  ({'suffix1': u'o', 'suffix2': u'Bo'}, 'female'),
#  ({'suffix1': u'e', 'suffix2': u'oe'}, 'male'),
#  ({'suffix1': u'a', 'suffix2': u'la'}, 'female'),
#  ({'suffix1': u'a', 'suffix2': u'na'}, 'female'),
#  ({'suffix1': u'e', 'suffix2': u'te'}, 'female'),
#  ({'suffix1': u'l', 'suffix2': u'il'}, 'female'),
#  ({'suffix1': u'e', 'suffix2': u'ce'}, 'male'),
#  ({'suffix1': u'e', 'suffix2': u'ie'}, 'male'),
#  ({'suffix1': u'o', 'suffix2': u'co'}, 'male'),
#  ({'suffix1': u'e', 'suffix2': u'ie'}, 'male'),
#  ({'suffix1': u'd', 'suffix2': u'nd'}, 'male'),
#  ({'suffix1': u'a', 'suffix2': u'na'}, 'female'),
#  ({'suffix1': u'e', 'suffix2': u'te'}, 'female'),
#  ({'suffix1': u'n', 'suffix2': u'nn'}, 'female'),
#  ({'suffix1': u'r', 'suffix2': u'er'}, 'female'),
#  ({'suffix1': u'r', 'suffix2': u'er'}, 'male'),
#  ({'suffix1': u'a', 'suffix2': u'ba'}, 'female'),
#  ({'suffix1': u'e', 'suffix2': u'oe'}, 'female'),
#  ({'suffix1': u'a', 'suffix2': u'da'}, 'female'),
#  ({'suffix1': u'd', 'suffix2': u'ld'}, 'male'),
#  ({'suffix1': u'i', 'suffix2': u'di'}, 'female'),
#  ({'suffix1': u'e', 'suffix2': u'ie'}, 'female'),
#  ({'suffix1': u'a', 'suffix2': u'ia'}, 'female'),
#  ({'suffix1': u'i', 'suffix2': u'ti'}, 'female'),
#  ({'suffix1': u'e', 'suffix2': u'ie'}, 'female'),
#  ({'suffix1': u'e', 'suffix2': u'ne'}, 'female'),
#  ({'suffix1': u'a', 'suffix2': u'ra'}, 'female'),
#  ({'suffix1': u'e', 'suffix2': u'ie'}, 'male'),
#  ({'suffix1': u'a', 'suffix2': u'na'}, 'female'),
#  ({'suffix1': u'e', 'suffix2': u'te'}, 'female'),
#  ({'suffix1': u'a', 'suffix2': u'ia'}, 'female'),
#  ({'suffix1': u'e', 'suffix2': u'ne'}, 'female'),
#  ({'suffix1': u'y', 'suffix2': u'ry'}, 'female'),
#  ({'suffix1': u'k', 'suffix2': u'nk'}, 'male'),
#  ({'suffix1': u'a', 'suffix2': u'ca'}, 'female'),
#  ({'suffix1': u'n', 'suffix2': u'in'}, 'male'),
#  ({'suffix1': u't', 'suffix2': u'it'}, 'male'),
#  ({'suffix1': u'e', 'suffix2': u'ue'}, 'male'),
#  ({'suffix1': u's', 'suffix2': u'is'}, 'male'),
#  ({'suffix1': u'e', 'suffix2': u'ie'}, 'male'),
#  ({'suffix1': u'e', 'suffix2': u'ce'}, 'male'),
#  ({'suffix1': u'e', 'suffix2': u'le'}, 'female'),
#  ({'suffix1': u'd', 'suffix2': u'id'}, 'male'),
#  ({'suffix1': u'i', 'suffix2': u'li'}, 'female'),
#  ({'suffix1': u'e', 'suffix2': u'ie'}, 'male'),
#  ({'suffix1': u'e', 'suffix2': u'ne'}, 'female'),
#  ({'suffix1': u'a', 'suffix2': u'na'}, 'female'),
#  ({'suffix1': u'n', 'suffix2': u'nn'}, 'female'),
#  ({'suffix1': u'd', 'suffix2': u'ed'}, 'male'),
#  ({'suffix1': u'o', 'suffix2': u'no'}, 'male'),
#  ({'suffix1': u'n', 'suffix2': u'on'}, 'male'),
#  ({'suffix1': u'l', 'suffix2': u'al'}, 'male'),
#  ({'suffix1': u'd', 'suffix2': u'id'}, 'male'),
#  ({'suffix1': u'e', 'suffix2': u'ie'}, 'female'),
#  ({'suffix1': u'e', 'suffix2': u'ie'}, 'female'),
#  ({'suffix1': u's', 'suffix2': u'ns'}, 'male'),
#  ({'suffix1': u'e', 'suffix2': u'ne'}, 'female'),
#  ({'suffix1': u'n', 'suffix2': u'in'}, 'male'),
#  ({'suffix1': u'a', 'suffix2': u'ta'}, 'female'),
#  ({'suffix1': u'a', 'suffix2': u'da'}, 'female'),
#  ({'suffix1': u'e', 'suffix2': u'ce'}, 'female'),
#  ({'suffix1': u'y', 'suffix2': u'ty'}, 'male'),
#  ({'suffix1': u'n', 'suffix2': u'in'}, 'female'),
#  ({'suffix1': u'n', 'suffix2': u'en'}, 'female'),
#  ({'suffix1': u'a', 'suffix2': u'ia'}, 'female'),
#  ({'suffix1': u'y', 'suffix2': u'dy'}, 'female'),
#  ({'suffix1': u'e', 'suffix2': u'ie'}, 'female'),
#  ({'suffix1': u'a', 'suffix2': u'na'}, 'female'),
#  ({'suffix1': u'n', 'suffix2': u'an'}, 'male'),
#  ({'suffix1': u'y', 'suffix2': u'ey'}, 'female'),
#  ({'suffix1': u'e', 'suffix2': u'ne'}, 'male'),
#  ({'suffix1': u'e', 'suffix2': u'se'}, 'female'),
#  ({'suffix1': u'c', 'suffix2': u'ic'}, 'male'),
#  ({'suffix1': u'a', 'suffix2': u'ha'}, 'female'),
#  ({'suffix1': u'n', 'suffix2': u'en'}, 'female'),
#  ({'suffix1': u'd', 'suffix2': u'ld'}, 'male'),
#  ({'suffix1': u'e', 'suffix2': u'me'}, 'male'),
#  ({'suffix1': u'e', 'suffix2': u'ie'}, 'male'),
#  ({'suffix1': u'y', 'suffix2': u'ey'}, 'female'),
#  ({'suffix1': u'o', 'suffix2': u'ho'}, 'male'),
#  ({'suffix1': u'o', 'suffix2': u'lo'}, 'female'),
#  ({'suffix1': u'e', 'suffix2': u'ne'}, 'female'),
#  ({'suffix1': u'a', 'suffix2': u'na'}, 'female'),
#  ({'suffix1': u'e', 'suffix2': u'ne'}, 'male'),
#  ({'suffix1': u'e', 'suffix2': u'ie'}, 'female'),
#  ({'suffix1': u'a', 'suffix2': u'da'}, 'female'),
#  ({'suffix1': u'e', 'suffix2': u'de'}, 'female'),
#  ({'suffix1': u'i', 'suffix2': u'gi'}, 'female'),
#  ({'suffix1': u'l', 'suffix2': u'll'}, 'female'),
#  ({'suffix1': u'n', 'suffix2': u'on'}, 'male'),
#  ({'suffix1': u'e', 'suffix2': u'ne'}, 'female'),
#  ({'suffix1': u'a', 'suffix2': u'da'}, 'female'),
#  ({'suffix1': u'a', 'suffix2': u'na'}, 'female'),
#  ({'suffix1': u'a', 'suffix2': u'da'}, 'female'),
#  ({'suffix1': u'a', 'suffix2': u'ta'}, 'female'),
#  ({'suffix1': u'a', 'suffix2': u'ka'}, 'female'),
#  ({'suffix1': u'd', 'suffix2': u'rd'}, 'male'),
#  ({'suffix1': u'a', 'suffix2': u'ea'}, 'female'),
#  ({'suffix1': u'a', 'suffix2': u'la'}, 'female'),
#  ({'suffix1': u'a', 'suffix2': u'sa'}, 'female'),
#  ({'suffix1': u'a', 'suffix2': u'ra'}, 'female'),
#  ({'suffix1': u'e', 'suffix2': u'ee'}, 'female'),
#  ({'suffix1': u'a', 'suffix2': u'sa'}, 'female'),
#  ({'suffix1': u'd', 'suffix2': u'ed'}, 'male'),
#  ({'suffix1': u'n', 'suffix2': u'on'}, 'male'),
#  ({'suffix1': u'y', 'suffix2': u'gy'}, 'female'),
#  ({'suffix1': u'a', 'suffix2': u'na'}, 'female'),
#  ({'suffix1': u'a', 'suffix2': u'na'}, 'female'),
#  ({'suffix1': u'y', 'suffix2': u'ry'}, 'male'),
#  ({'suffix1': u'e', 'suffix2': u'ie'}, 'female'),
#  ({'suffix1': u't', 'suffix2': u'it'}, 'female'),
#  ({'suffix1': u'a', 'suffix2': u'na'}, 'female'),
#  ({'suffix1': u'a', 'suffix2': u'ra'}, 'female'),
#  ({'suffix1': u'a', 'suffix2': u'na'}, 'female'),
#  ({'suffix1': u't', 'suffix2': u'lt'}, 'male'),
#  ({'suffix1': u'a', 'suffix2': u'ia'}, 'female'),
#  ({'suffix1': u'a', 'suffix2': u'ia'}, 'female'),
#  ({'suffix1': u'a', 'suffix2': u'ia'}, 'female'),
#  ({'suffix1': u'y', 'suffix2': u'ty'}, 'female'),
#  ({'suffix1': u'n', 'suffix2': u'on'}, 'male'),
#  ({'suffix1': u'a', 'suffix2': u'ia'}, 'female'),
#  ({'suffix1': u'a', 'suffix2': u'ra'}, 'female'),
#  ({'suffix1': u'e', 'suffix2': u'ce'}, 'female'),
#  ({'suffix1': u'h', 'suffix2': u'sh'}, 'female'),
#  ({'suffix1': u'n', 'suffix2': u'en'}, 'male'),
#  ({'suffix1': u'l', 'suffix2': u'il'}, 'female'),
#  ({'suffix1': u'i', 'suffix2': u'ri'}, 'female'),
#  ({'suffix1': u'm', 'suffix2': u'am'}, 'female'),
#  ({'suffix1': u'n', 'suffix2': u'en'}, 'female'),
#  ({'suffix1': u'r', 'suffix2': u'er'}, 'male'),
#  ({'suffix1': u'a', 'suffix2': u'da'}, 'female'),
#  ({'suffix1': u'a', 'suffix2': u'na'}, 'female'),
#  ({'suffix1': u'r', 'suffix2': u'or'}, 'male'),
#  ({'suffix1': u'l', 'suffix2': u'al'}, 'male'),
#  ({'suffix1': u'h', 'suffix2': u'ah'}, 'female'),
#  ({'suffix1': u'r', 'suffix2': u'or'}, 'female'),
#  ({'suffix1': u'a', 'suffix2': u'da'}, 'female'),
#  ({'suffix1': u'k', 'suffix2': u'ck'}, 'male'),
#  ({'suffix1': u'e', 'suffix2': u'ie'}, 'female'),
#  ({'suffix1': u'r', 'suffix2': u'er'}, 'male'),
#  ({'suffix1': u'a', 'suffix2': u'ta'}, 'female'),
#  ({'suffix1': u'n', 'suffix2': u'on'}, 'male'),
#  ({'suffix1': u'a', 'suffix2': u'sa'}, 'female'),
#  ({'suffix1': u'o', 'suffix2': u'so'}, 'male'),
#  ({'suffix1': u'e', 'suffix2': u'ce'}, 'male'),
#  ({'suffix1': u'k', 'suffix2': u'ck'}, 'male'),
#  ({'suffix1': u't', 'suffix2': u'rt'}, 'male'),
#  ({'suffix1': u'i', 'suffix2': u'ri'}, 'male'),
#  ({'suffix1': u'a', 'suffix2': u'ta'}, 'female'),
#  ({'suffix1': u'a', 'suffix2': u'ia'}, 'female'),
#  ({'suffix1': u'e', 'suffix2': u'ne'}, 'female'),
#  ({'suffix1': u'i', 'suffix2': u'li'}, 'female'),
#  ({'suffix1': u'y', 'suffix2': u'ly'}, 'male'),
#  ({'suffix1': u'i', 'suffix2': u'mi'}, 'female'),
#  ({'suffix1': u'l', 'suffix2': u'el'}, 'female'),
#  ({'suffix1': u'n', 'suffix2': u'in'}, 'male'),
#  ({'suffix1': u'n', 'suffix2': u'yn'}, 'female'),
#  ({'suffix1': u'n', 'suffix2': u'en'}, 'male'),
#  ({'suffix1': u'i', 'suffix2': u'di'}, 'female'),
#  ({'suffix1': u'n', 'suffix2': u'an'}, 'female'),
#  ({'suffix1': u'e', 'suffix2': u'le'}, 'female'),
#  ({'suffix1': u'd', 'suffix2': u'ed'}, 'female'),
#  ({'suffix1': u'f', 'suffix2': u'ff'}, 'male'),
#  ({'suffix1': u'e', 'suffix2': u'te'}, 'female'),
#  ({'suffix1': u'e', 'suffix2': u'ne'}, 'male'),
#  ({'suffix1': u'e', 'suffix2': u'me'}, 'male'),
#  ({'suffix1': u'y', 'suffix2': u'ey'}, 'female'),
#  ({'suffix1': u'y', 'suffix2': u'my'}, 'male'),
#  ({'suffix1': u'm', 'suffix2': u'im'}, 'male'),
#  ({'suffix1': u'e', 'suffix2': u'ne'}, 'female'),
#  ({'suffix1': u'a', 'suffix2': u'na'}, 'female'),
#  ({'suffix1': u'e', 'suffix2': u'ge'}, 'male'),
#  ({'suffix1': u'e', 'suffix2': u'ne'}, 'female'),
#  ({'suffix1': u'a', 'suffix2': u'da'}, 'female'),
#  ({'suffix1': u'n', 'suffix2': u'en'}, 'male'),
#  ({'suffix1': u'n', 'suffix2': u'an'}, 'male'),
#  ({'suffix1': u'n', 'suffix2': u'on'}, 'male'),
#  ({'suffix1': u'l', 'suffix2': u'el'}, 'female'),
#  ({'suffix1': u'a', 'suffix2': u'sa'}, 'female'),
#  ({'suffix1': u'o', 'suffix2': u'go'}, 'male'),
#  ({'suffix1': u'y', 'suffix2': u'ny'}, 'male'),
#  ({'suffix1': u'n', 'suffix2': u'in'}, 'male'),
#  ({'suffix1': u'a', 'suffix2': u'na'}, 'female'),
#  ({'suffix1': u'y', 'suffix2': u'ty'}, 'male'),
#  ({'suffix1': u'a', 'suffix2': u'ia'}, 'female'),
#  ({'suffix1': u'y', 'suffix2': u'ny'}, 'male'),
#  ({'suffix1': u'a', 'suffix2': u'ia'}, 'female'),
#  ({'suffix1': u'a', 'suffix2': u'sa'}, 'female'),
#  ({'suffix1': u'a', 'suffix2': u'ra'}, 'female'),
#  ({'suffix1': u'e', 'suffix2': u'ne'}, 'female'),
#  ({'suffix1': u'v', 'suffix2': u'ov'}, 'male'),
#  ({'suffix1': u'e', 'suffix2': u'ne'}, 'female'),
#  ({'suffix1': u'y', 'suffix2': u'sy'}, 'female'),
#  ({'suffix1': u'a', 'suffix2': u'la'}, 'female'),
#  ({'suffix1': u'a', 'suffix2': u'ra'}, 'female'),
#  ({'suffix1': u'e', 'suffix2': u'le'}, 'female'),
#  ({'suffix1': u'a', 'suffix2': u'ia'}, 'female'),
#  ({'suffix1': u'm', 'suffix2': u'lm'}, 'male'),
#  ({'suffix1': u'a', 'suffix2': u'ia'}, 'female'),
#  ({'suffix1': u'e', 'suffix2': u'le'}, 'female'),
#  ({'suffix1': u'a', 'suffix2': u'va'}, 'female'),
#  ({'suffix1': u'e', 'suffix2': u'me'}, 'male'),
#  ({'suffix1': u'n', 'suffix2': u'on'}, 'male'),
#  ({'suffix1': u't', 'suffix2': u'rt'}, 'male'),
#  ({'suffix1': u's', 'suffix2': u'ys'}, 'female'),
#  ({'suffix1': u'l', 'suffix2': u'el'}, 'male'),
#  ({'suffix1': u'n', 'suffix2': u'en'}, 'female'),
#  ({'suffix1': u'e', 'suffix2': u'be'}, 'female'),
#  ({'suffix1': u'e', 'suffix2': u'ee'}, 'female'),
#  ({'suffix1': u'l', 'suffix2': u'el'}, 'male'),
#  ({'suffix1': u'l', 'suffix2': u'al'}, 'male'),
#  ({'suffix1': u'e', 'suffix2': u'ne'}, 'female'),
#  ({'suffix1': u'i', 'suffix2': u'mi'}, 'female'),
#  ({'suffix1': u'l', 'suffix2': u'll'}, 'male'),
#  ({'suffix1': u'n', 'suffix2': u'in'}, 'female'),
#  ({'suffix1': u'a', 'suffix2': u'na'}, 'female'),
#  ({'suffix1': u's', 'suffix2': u'es'}, 'male'),
#  ({'suffix1': u'n', 'suffix2': u'on'}, 'male'),
#  ({'suffix1': u'e', 'suffix2': u'ge'}, 'male'),
#  ({'suffix1': u'a', 'suffix2': u'na'}, 'female'),
#  ({'suffix1': u'a', 'suffix2': u'ia'}, 'female'),
#  ({'suffix1': u'e', 'suffix2': u'le'}, 'female'),
#  ({'suffix1': u'n', 'suffix2': u'an'}, 'male'),
#  ({'suffix1': u't', 'suffix2': u'it'}, 'female'),
#  ({'suffix1': u'y', 'suffix2': u'ry'}, 'male'),
#  ({'suffix1': u'a', 'suffix2': u'sa'}, 'female'),
#  ({'suffix1': u'n', 'suffix2': u'on'}, 'male'),
#  ({'suffix1': u'e', 'suffix2': u'ie'}, 'female'),
#  ({'suffix1': u'e', 'suffix2': u'ee'}, 'male'),
#  ({'suffix1': u'l', 'suffix2': u'il'}, 'female'),
#  ({'suffix1': u'n', 'suffix2': u'on'}, 'male'),
#  ({'suffix1': u'e', 'suffix2': u'ae'}, 'female'),
#  ({'suffix1': u'a', 'suffix2': u'na'}, 'female'),
#  ({'suffix1': u'l', 'suffix2': u'll'}, 'male'),
#  ({'suffix1': u'e', 'suffix2': u're'}, 'male'),
#  ({'suffix1': u'l', 'suffix2': u'll'}, 'male'),
#  ({'suffix1': u't', 'suffix2': u'rt'}, 'male'),
#  ({'suffix1': u'i', 'suffix2': u'di'}, 'female'),
#  ({'suffix1': u'e', 'suffix2': u'ne'}, 'female'),
#  ({'suffix1': u'a', 'suffix2': u'ra'}, 'female'),
#  ({'suffix1': u's', 'suffix2': u'os'}, 'male'),
#  ({'suffix1': u'c', 'suffix2': u'ic'}, 'male'),
#  ({'suffix1': u'r', 'suffix2': u'er'}, 'male'),
#  ({'suffix1': u'y', 'suffix2': u'dy'}, 'male'),
#  ({'suffix1': u'a', 'suffix2': u'la'}, 'female'),
#  ({'suffix1': u'd', 'suffix2': u'ld'}, 'male'),
#  ({'suffix1': u'y', 'suffix2': u'ty'}, 'female'),
#  ({'suffix1': u'a', 'suffix2': u'na'}, 'female'),
#  ({'suffix1': u'n', 'suffix2': u'an'}, 'male'),
#  ({'suffix1': u's', 'suffix2': u'us'}, 'male'),
#  ({'suffix1': u's', 'suffix2': u'us'}, 'male'),
#  ({'suffix1': u'n', 'suffix2': u'en'}, 'male'),
#  ({'suffix1': u'e', 'suffix2': u'ne'}, 'female'),
#  ({'suffix1': u'm', 'suffix2': u'am'}, 'female'),
#  ({'suffix1': u'a', 'suffix2': u'na'}, 'female'),
#  ({'suffix1': u's', 'suffix2': u'es'}, 'male'),
#  ({'suffix1': u'y', 'suffix2': u'Cy'}, 'male'),
#  ({'suffix1': u'l', 'suffix2': u'al'}, 'female'),
#  ({'suffix1': u'o', 'suffix2': u'to'}, 'male'),
#  ({'suffix1': u'a', 'suffix2': u'ia'}, 'female'),
#  ({'suffix1': u'e', 'suffix2': u'te'}, 'female'),
#  ({'suffix1': u'y', 'suffix2': u'ky'}, 'male'),
#  ({'suffix1': u'c', 'suffix2': u'ic'}, 'male'),
#  ({'suffix1': u'd', 'suffix2': u'rd'}, 'male'),
#  ({'suffix1': u'e', 'suffix2': u'pe'}, 'female'),
#  ({'suffix1': u'm', 'suffix2': u'am'}, 'male'),
#  ({'suffix1': u'n', 'suffix2': u'nn'}, 'female'),
#  ({'suffix1': u'e', 'suffix2': u'te'}, 'male'),
#  ({'suffix1': u'r', 'suffix2': u'er'}, 'female'),
#  ({'suffix1': u'l', 'suffix2': u'll'}, 'male'),
#  ({'suffix1': u'e', 'suffix2': u'ne'}, 'female'),
#  ({'suffix1': u'e', 'suffix2': u'te'}, 'female'),
#  ({'suffix1': u'a', 'suffix2': u'ra'}, 'female'),
#  ({'suffix1': u'h', 'suffix2': u'ah'}, 'female'),
#  ({'suffix1': u'n', 'suffix2': u'on'}, 'female'),
#  ({'suffix1': u'a', 'suffix2': u'ta'}, 'female'),
#  ({'suffix1': u's', 'suffix2': u'us'}, 'male'),
#  ({'suffix1': u'e', 'suffix2': u'le'}, 'female'),
#  ({'suffix1': u'y', 'suffix2': u'sy'}, 'female'),
#  ({'suffix1': u's', 'suffix2': u'es'}, 'male'),
#  ({'suffix1': u'i', 'suffix2': u'li'}, 'female'),
#  ({'suffix1': u'n', 'suffix2': u'yn'}, 'male'),
#  ({'suffix1': u'e', 'suffix2': u'se'}, 'female'),
#  ({'suffix1': u'd', 'suffix2': u'ad'}, 'male'),
#  ({'suffix1': u'n', 'suffix2': u'in'}, 'female'),
#  ({'suffix1': u'y', 'suffix2': u'ny'}, 'female'),
#  ({'suffix1': u'n', 'suffix2': u'in'}, 'male'),
#  ({'suffix1': u'n', 'suffix2': u'an'}, 'male'),
#  ({'suffix1': u'y', 'suffix2': u'dy'}, 'female'),
#  ({'suffix1': u'n', 'suffix2': u'nn'}, 'male'),
#  ({'suffix1': u'y', 'suffix2': u'ey'}, 'female'),
#  ({'suffix1': u'e', 'suffix2': u'ie'}, 'female'),
#  ({'suffix1': u'y', 'suffix2': u'ey'}, 'female'),
#  ({'suffix1': u'a', 'suffix2': u'va'}, 'female'),
#  ({'suffix1': u'y', 'suffix2': u'ey'}, 'female'),
#  ({'suffix1': u'y', 'suffix2': u'dy'}, 'female'),
#  ({'suffix1': u'e', 'suffix2': u'ne'}, 'female'),
#  ({'suffix1': u'e', 'suffix2': u'ie'}, 'female'),
#  ({'suffix1': u'a', 'suffix2': u'ra'}, 'female'),
#  ({'suffix1': u'a', 'suffix2': u'ia'}, 'female'),
#  ({'suffix1': u'i', 'suffix2': u'ni'}, 'male'),
#  ({'suffix1': u'e', 'suffix2': u'ne'}, 'male'),
#  ({'suffix1': u'n', 'suffix2': u'yn'}, 'female'),
#  ({'suffix1': u'o', 'suffix2': u'lo'}, 'male'),
#  ({'suffix1': u'e', 'suffix2': u'ne'}, 'female'),
#  ({'suffix1': u'i', 'suffix2': u'ni'}, 'female'),
#  ({'suffix1': u's', 'suffix2': u'is'}, 'male'),
#  ({'suffix1': u'a', 'suffix2': u'na'}, 'female'),
#  ({'suffix1': u'a', 'suffix2': u'na'}, 'female'),
#  ({'suffix1': u'o', 'suffix2': u'do'}, 'male'),
#  ({'suffix1': u'i', 'suffix2': u'bi'}, 'female'),
#  ({'suffix1': u'a', 'suffix2': u'ra'}, 'female'),
#  ({'suffix1': u'r', 'suffix2': u'ar'}, 'male'),
#  ({'suffix1': u'e', 'suffix2': u'ne'}, 'female'),
#  ({'suffix1': u'y', 'suffix2': u'dy'}, 'male'),
#  ({'suffix1': u'y', 'suffix2': u'ey'}, 'male'),
#  ({'suffix1': u'y', 'suffix2': u'ny'}, 'female'),
#  ({'suffix1': u'd', 'suffix2': u'nd'}, 'male'),
#  ({'suffix1': u'e', 'suffix2': u'te'}, 'female'),
#  ({'suffix1': u'e', 'suffix2': u'ie'}, 'female'),
#  ({'suffix1': u'y', 'suffix2': u'sy'}, 'female'),
#  ({'suffix1': u'e', 'suffix2': u'ie'}, 'female'),
#  ({'suffix1': u'a', 'suffix2': u'da'}, 'female'),
#  ({'suffix1': u's', 'suffix2': u'ss'}, 'male'),
#  ({'suffix1': u'y', 'suffix2': u'ny'}, 'male'),
#  ({'suffix1': u'i', 'suffix2': u'ni'}, 'female'),
#  ({'suffix1': u't', 'suffix2': u'ot'}, 'male'),
#  ({'suffix1': u'a', 'suffix2': u'ha'}, 'male'),
#  ({'suffix1': u'a', 'suffix2': u'da'}, 'female'),
#  ({'suffix1': u'e', 'suffix2': u'ne'}, 'female'),
#  ({'suffix1': u'i', 'suffix2': u'ei'}, 'male'),
#  ({'suffix1': u'a', 'suffix2': u'ra'}, 'female'),
#  ({'suffix1': u'i', 'suffix2': u'ti'}, 'female'),
#  ({'suffix1': u'e', 'suffix2': u'ee'}, 'female'),
#  ({'suffix1': u'y', 'suffix2': u'ry'}, 'female'),
#  ({'suffix1': u'y', 'suffix2': u'ry'}, 'male'),
#  ({'suffix1': u'e', 'suffix2': u'le'}, 'female'),
#  ({'suffix1': u's', 'suffix2': u'is'}, 'male'),
#  ({'suffix1': u'a', 'suffix2': u'ra'}, 'female'),
#  ({'suffix1': u'i', 'suffix2': u'ni'}, 'female'),
#  ({'suffix1': u'y', 'suffix2': u'ey'}, 'male'),
#  ({'suffix1': u'e', 'suffix2': u'ne'}, 'female'),
#  ({'suffix1': u's', 'suffix2': u'us'}, 'male'),
#  ({'suffix1': u's', 'suffix2': u'is'}, 'female'),
#  ({'suffix1': u'y', 'suffix2': u'by'}, 'male'),
#  ({'suffix1': u'e', 'suffix2': u'ee'}, 'female'),
#  ({'suffix1': u'a', 'suffix2': u'ia'}, 'female'),
#  ({'suffix1': u'n', 'suffix2': u'an'}, 'female'),
#  ({'suffix1': u'i', 'suffix2': u'ci'}, 'female'),
#  ({'suffix1': u'e', 'suffix2': u'ne'}, 'male'),
#  ({'suffix1': u'l', 'suffix2': u'el'}, 'female'),
#  ({'suffix1': u'a', 'suffix2': u'ea'}, 'female'),
#  ({'suffix1': u'a', 'suffix2': u'ya'}, 'male'),
#  ({'suffix1': u'e', 'suffix2': u'ne'}, 'female'),
#  ({'suffix1': u'e', 'suffix2': u'ue'}, 'female'),
#  ({'suffix1': u'i', 'suffix2': u'mi'}, 'female'),
#  ({'suffix1': u'd', 'suffix2': u'nd'}, 'male'),
#  ({'suffix1': u'y', 'suffix2': u'ly'}, 'female'),
#  ({'suffix1': u'd', 'suffix2': u'ud'}, 'female'),
#  ({'suffix1': u'l', 'suffix2': u'el'}, 'male'),
#  ({'suffix1': u'v', 'suffix2': u'ev'}, 'male'),
#  ({'suffix1': u'a', 'suffix2': u'da'}, 'female'),
#  ({'suffix1': u'y', 'suffix2': u'ey'}, 'female'),
#  ({'suffix1': u's', 'suffix2': u'as'}, 'male'),
#  ({'suffix1': u'n', 'suffix2': u'an'}, 'male'),
#  ({'suffix1': u'a', 'suffix2': u'ga'}, 'female'),
#  ({'suffix1': u'e', 'suffix2': u'ne'}, 'female'),
#  ({'suffix1': u'o', 'suffix2': u'do'}, 'male'),
#  ({'suffix1': u'y', 'suffix2': u'ey'}, 'female'),
#  ({'suffix1': u'a', 'suffix2': u'na'}, 'female'),
#  ({'suffix1': u's', 'suffix2': u'us'}, 'male'),
#  ({'suffix1': u'x', 'suffix2': u'ix'}, 'female'),
#  ({'suffix1': u'e', 'suffix2': u'ne'}, 'female'),
#  ({'suffix1': u'i', 'suffix2': u'si'}, 'female'),
#  ({'suffix1': u'd', 'suffix2': u'ed'}, 'female'),
#  ({'suffix1': u'a', 'suffix2': u'ia'}, 'female'),
#  ({'suffix1': u'n', 'suffix2': u'on'}, 'male'),
#  ({'suffix1': u'a', 'suffix2': u'ma'}, 'female'),
#  ({'suffix1': u'i', 'suffix2': u'mi'}, 'female'),
#  ({'suffix1': u'e', 'suffix2': u'ne'}, 'female'),
#  ({'suffix1': u'l', 'suffix2': u'll'}, 'male'),
#  ({'suffix1': u'e', 'suffix2': u'ee'}, 'female'),
#  ({'suffix1': u'l', 'suffix2': u'el'}, 'female'),
#  ({'suffix1': u'a', 'suffix2': u'ia'}, 'female'),
#  ({'suffix1': u'a', 'suffix2': u'ta'}, 'female'),
#  ({'suffix1': u'n', 'suffix2': u'nn'}, 'female'),
#  ({'suffix1': u'e', 'suffix2': u'ie'}, 'male'),
#  ({'suffix1': u'a', 'suffix2': u'ia'}, 'female'),
#  ({'suffix1': u'e', 'suffix2': u'ne'}, 'female'),
#  ({'suffix1': u'e', 'suffix2': u'ee'}, 'male'),
#  ({'suffix1': u'r', 'suffix2': u'er'}, 'female'),
#  ({'suffix1': u'e', 'suffix2': u'ie'}, 'female'),
#  ({'suffix1': u'n', 'suffix2': u'on'}, 'male'),
#  ({'suffix1': u'y', 'suffix2': u'ry'}, 'female'),
#  ({'suffix1': u'l', 'suffix2': u'il'}, 'male'),
#  ({'suffix1': u'e', 'suffix2': u'ne'}, 'male'),
#  ({'suffix1': u'e', 'suffix2': u'ie'}, 'female'),
#  ({'suffix1': u'n', 'suffix2': u'yn'}, 'female'),
#  ({'suffix1': u'e', 'suffix2': u'ie'}, 'female'),
#  ({'suffix1': u'e', 'suffix2': u'ee'}, 'female'),
#  ({'suffix1': u's', 'suffix2': u'as'}, 'male'),
#  ({'suffix1': u'e', 'suffix2': u'ie'}, 'female'),
#  ({'suffix1': u'a', 'suffix2': u'da'}, 'female'),
#  ({'suffix1': u'n', 'suffix2': u'yn'}, 'female'),
#  ({'suffix1': u'n', 'suffix2': u'in'}, 'female'),
#  ({'suffix1': u'a', 'suffix2': u'ca'}, 'female'),
#  ({'suffix1': u'a', 'suffix2': u'sa'}, 'female'),
#  ({'suffix1': u'e', 'suffix2': u'ie'}, 'male'),
#  ({'suffix1': u'a', 'suffix2': u'la'}, 'female'),
#  ({'suffix1': u'a', 'suffix2': u'aa'}, 'male'),
#  ({'suffix1': u'i', 'suffix2': u'bi'}, 'female'),
#  ({'suffix1': u'e', 'suffix2': u'ne'}, 'female'),
#  ({'suffix1': u't', 'suffix2': u'nt'}, 'male'),
#  ({'suffix1': u'l', 'suffix2': u'yl'}, 'female'),
#  ({'suffix1': u'n', 'suffix2': u'an'}, 'male'),
#  ({'suffix1': u'e', 'suffix2': u'ce'}, 'male'),
#  ({'suffix1': u'e', 'suffix2': u'ne'}, 'female'),
#  ({'suffix1': u'n', 'suffix2': u'yn'}, 'female'),
#  ({'suffix1': u'n', 'suffix2': u'on'}, 'male'),
#  ({'suffix1': u'a', 'suffix2': u'ta'}, 'female'),
#  ({'suffix1': u'e', 'suffix2': u'ie'}, 'female'),
#  ({'suffix1': u'n', 'suffix2': u'nn'}, 'female'),
#  ({'suffix1': u'n', 'suffix2': u'nn'}, 'female'),
#  ({'suffix1': u'e', 'suffix2': u'ne'}, 'female'),
#  ({'suffix1': u'a', 'suffix2': u'ra'}, 'female'),
#  ({'suffix1': u'a', 'suffix2': u'la'}, 'female'),
#  ({'suffix1': u'e', 'suffix2': u'ie'}, 'female'),
#  ({'suffix1': u'r', 'suffix2': u'or'}, 'male'),
#  ({'suffix1': u'r', 'suffix2': u'er'}, 'male'),
#  ({'suffix1': u'l', 'suffix2': u'el'}, 'male'),
#  ({'suffix1': u'y', 'suffix2': u'fy'}, 'male'),
#  ({'suffix1': u'a', 'suffix2': u'ma'}, 'female'),
#  ({'suffix1': u'e', 'suffix2': u'ne'}, 'female'),
#  ({'suffix1': u'e', 'suffix2': u'ie'}, 'male'),
#  ({'suffix1': u'e', 'suffix2': u'ee'}, 'female'),
#  ({'suffix1': u'e', 'suffix2': u'ie'}, 'female'),
#  ({'suffix1': u'e', 'suffix2': u'ne'}, 'female'),
#  ({'suffix1': u'i', 'suffix2': u'ni'}, 'female'),
#  ({'suffix1': u'a', 'suffix2': u'ra'}, 'female'),
#  ({'suffix1': u's', 'suffix2': u'us'}, 'male'),
#  ({'suffix1': u'n', 'suffix2': u'yn'}, 'female'),
#  ({'suffix1': u'e', 'suffix2': u'ne'}, 'female'),
#  ({'suffix1': u'e', 'suffix2': u'ne'}, 'female'),
#  ({'suffix1': u'n', 'suffix2': u'un'}, 'female'),
#  ({'suffix1': u'e', 'suffix2': u'ne'}, 'female'),
#  ({'suffix1': u'a', 'suffix2': u'ta'}, 'female'),
#  ({'suffix1': u'g', 'suffix2': u'rg'}, 'female'),
#  ({'suffix1': u'a', 'suffix2': u'ia'}, 'female'),
#  ({'suffix1': u'a', 'suffix2': u'la'}, 'female'),
#  ({'suffix1': u'n', 'suffix2': u'on'}, 'female'),
#  ({'suffix1': u'e', 'suffix2': u're'}, 'female'),
#  ({'suffix1': u'y', 'suffix2': u'dy'}, 'female'),
#  ({'suffix1': u'l', 'suffix2': u'll'}, 'male'),
#  ({'suffix1': u'a', 'suffix2': u'la'}, 'female'),
#  ({'suffix1': u's', 'suffix2': u'as'}, 'male'),
#  ({'suffix1': u'n', 'suffix2': u'in'}, 'male'),
#  ({'suffix1': u'a', 'suffix2': u'na'}, 'female'),
#  ({'suffix1': u'y', 'suffix2': u'ey'}, 'female'),
#  ({'suffix1': u'r', 'suffix2': u'ar'}, 'male'),
#  ({'suffix1': u'y', 'suffix2': u'ey'}, 'male'),
#  ({'suffix1': u'e', 'suffix2': u'se'}, 'female'),
#  ({'suffix1': u'o', 'suffix2': u'go'}, 'male'),
#  ({'suffix1': u'y', 'suffix2': u'ey'}, 'female'),
#  ({'suffix1': u'y', 'suffix2': u'ky'}, 'male'),
#  ({'suffix1': u'a', 'suffix2': u'la'}, 'female'),
#  ({'suffix1': u'e', 'suffix2': u'he'}, 'female'),
#  ({'suffix1': u'n', 'suffix2': u'in'}, 'female'),
#  ({'suffix1': u'l', 'suffix2': u'al'}, 'female'),
#  ({'suffix1': u'a', 'suffix2': u'ra'}, 'female'),
#  ({'suffix1': u'b', 'suffix2': u'ob'}, 'male'),
#  ({'suffix1': u'e', 'suffix2': u'ie'}, 'female'),
#  ({'suffix1': u'e', 'suffix2': u've'}, 'male'),
#  ({'suffix1': u'a', 'suffix2': u'na'}, 'female'),
#  ({'suffix1': u'o', 'suffix2': u'no'}, 'male'),
#  ({'suffix1': u'n', 'suffix2': u'yn'}, 'female'),
#  ({'suffix1': u'a', 'suffix2': u'na'}, 'female'),
#  ({'suffix1': u'e', 'suffix2': u'ne'}, 'male'),
#  ({'suffix1': u't', 'suffix2': u'lt'}, 'male'),
#  ({'suffix1': u'a', 'suffix2': u'ra'}, 'female'),
#  ({'suffix1': u'n', 'suffix2': u'on'}, 'female'),
#  ({'suffix1': u'y', 'suffix2': u'fy'}, 'male'),
#  ({'suffix1': u'd', 'suffix2': u'rd'}, 'female'),
#  ({'suffix1': u'r', 'suffix2': u'er'}, 'male'),
#  ({'suffix1': u'e', 'suffix2': u'ne'}, 'female'),
#  ({'suffix1': u'v', 'suffix2': u'rv'}, 'male'),
#  ({'suffix1': u'e', 'suffix2': u'se'}, 'female'),
#  ({'suffix1': u'e', 'suffix2': u'ue'}, 'female'),
#  ({'suffix1': u'y', 'suffix2': u'ey'}, 'male'),
#  ({'suffix1': u'a', 'suffix2': u'na'}, 'female'),
#  ({'suffix1': u'i', 'suffix2': u'ri'}, 'female'),
#  ({'suffix1': u'e', 'suffix2': u'ie'}, 'female'),
#  ({'suffix1': u'e', 'suffix2': u'ie'}, 'female'),
#  ({'suffix1': u'y', 'suffix2': u'ty'}, 'female'),
#  ({'suffix1': u'a', 'suffix2': u'ia'}, 'female'),
#  ({'suffix1': u'y', 'suffix2': u'ny'}, 'male'),
#  ({'suffix1': u't', 'suffix2': u'rt'}, 'male'),
#  ({'suffix1': u'e', 'suffix2': u'ie'}, 'female'),
#  ({'suffix1': u'n', 'suffix2': u'in'}, 'female'),
#  ({'suffix1': u'a', 'suffix2': u'sa'}, 'female'),
#  ({'suffix1': u'e', 'suffix2': u'pe'}, 'male'),
#  ({'suffix1': u'a', 'suffix2': u'sa'}, 'female'),
#  ({'suffix1': u'e', 'suffix2': u'ie'}, 'female'),
#  ({'suffix1': u'e', 'suffix2': u've'}, 'male'),
#  ({'suffix1': u's', 'suffix2': u'is'}, 'male'),
#  ({'suffix1': u'e', 'suffix2': u'ge'}, 'male'),
#  ({'suffix1': u'a', 'suffix2': u'ia'}, 'female'),
#  ({'suffix1': u'e', 'suffix2': u'ie'}, 'female'),
#  ({'suffix1': u'n', 'suffix2': u'an'}, 'male'),
#  ({'suffix1': u'a', 'suffix2': u'na'}, 'female'),
#  ({'suffix1': u'e', 'suffix2': u'se'}, 'male'),
#  ({'suffix1': u'e', 'suffix2': u'ce'}, 'female'),
#  ({'suffix1': u'n', 'suffix2': u'nn'}, 'male'),
#  ({'suffix1': u'a', 'suffix2': u'la'}, 'female'),
#  ({'suffix1': u'n', 'suffix2': u'an'}, 'male'),
#  ({'suffix1': u'y', 'suffix2': u'ay'}, 'male'),
#  ({'suffix1': u'n', 'suffix2': u'yn'}, 'female'),
#  ({'suffix1': u'a', 'suffix2': u'na'}, 'female'),
#  ({'suffix1': u'e', 'suffix2': u're'}, 'female'),
#  ({'suffix1': u'a', 'suffix2': u'ta'}, 'female'),
#  ({'suffix1': u'a', 'suffix2': u'sa'}, 'female'),
#  ({'suffix1': u'o', 'suffix2': u'lo'}, 'male'),
#  ({'suffix1': u'l', 'suffix2': u'il'}, 'female'),
#  ({'suffix1': u's', 'suffix2': u'es'}, 'female'),
#  ({'suffix1': u'm', 'suffix2': u'im'}, 'male'),
#  ({'suffix1': u'r', 'suffix2': u'er'}, 'male'),
#  ({'suffix1': u'e', 'suffix2': u'ce'}, 'female'),
#  ({'suffix1': u'd', 'suffix2': u'od'}, 'male'),
#  ({'suffix1': u'a', 'suffix2': u'da'}, 'female'),
#  ({'suffix1': u'n', 'suffix2': u'in'}, 'female'),
#  ({'suffix1': u'a', 'suffix2': u'na'}, 'female'),
#  ({'suffix1': u'h', 'suffix2': u'gh'}, 'male'),
#  ({'suffix1': u'e', 'suffix2': u'ne'}, 'female'),
#  ({'suffix1': u'a', 'suffix2': u'ta'}, 'female'),
#  ({'suffix1': u'e', 'suffix2': u'ne'}, 'female'),
#  ({'suffix1': u'a', 'suffix2': u'na'}, 'female'),
#  ({'suffix1': u'e', 'suffix2': u'ie'}, 'female'),
#  ({'suffix1': u'y', 'suffix2': u'ny'}, 'male'),
#  ({'suffix1': u'a', 'suffix2': u'da'}, 'female'),
#  ({'suffix1': u's', 'suffix2': u'os'}, 'male'),
#  ({'suffix1': u'a', 'suffix2': u'va'}, 'female'),
#  ({'suffix1': u'l', 'suffix2': u'el'}, 'female'),
#  ({'suffix1': u'a', 'suffix2': u'la'}, 'female'),
#  ({'suffix1': u'e', 'suffix2': u'ee'}, 'female'),
#  ({'suffix1': u'e', 'suffix2': u'ne'}, 'female'),
#  ({'suffix1': u's', 'suffix2': u'us'}, 'male'),
#  ({'suffix1': u'r', 'suffix2': u'or'}, 'male'),
#  ({'suffix1': u'e', 'suffix2': u'le'}, 'female'),
#  ({'suffix1': u'a', 'suffix2': u'na'}, 'female'),
#  ({'suffix1': u'e', 'suffix2': u'ie'}, 'male'),
#  ({'suffix1': u'a', 'suffix2': u'sa'}, 'female'),
#  ({'suffix1': u'e', 'suffix2': u'ie'}, 'female'),
#  ({'suffix1': u's', 'suffix2': u'as'}, 'male'),
#  ({'suffix1': u'y', 'suffix2': u'dy'}, 'female'),
#  ({'suffix1': u'e', 'suffix2': u'ie'}, 'male'),
#  ({'suffix1': u'e', 'suffix2': u'ae'}, 'female'),
#  ...]

# %% [markdown]
# ## Doc Classification

# %%
from nltk.corpus import movie_reviews
documents = [(list(movie_reviews.words(fileid)), category)
              for category in movie_reviews.categories()
              for fileid in movie_reviews.fileids(category)]
random.shuffle(documents)

# %%
all_words = nltk.FreqDist(w.lower() for w in movie_reviews.words())
word_features = list(all_words)[:2000]

# %%
def document_features(document): 
    document_words = set(document)
    features = {}
    for word in word_features:
        features['contains({})'.format(word)] = (word in document_words)
    return features

# %%
featuresets = [(document_features(d), c) for (d,c) in documents]
train_set, test_set = featuresets[100:], featuresets[:100]
classifier = nltk.NaiveBayesClassifier.train(train_set)

# %%
print(nltk.classify.accuracy(classifier, test_set))
classifier.show_most_informative_features(5)
# Out:
# 0.7
# Most Informative Features
#           contains(sans) = True              neg : pos    =      9.0 : 1.0
#      contains(uplifting) = True              pos : neg    =      8.6 : 1.0
#   contains(effortlessly) = True              pos : neg    =      7.8 : 1.0
#     contains(mediocrity) = True              neg : pos    =      7.7 : 1.0
#           contains(hugo) = True              pos : neg    =      7.0 : 1.0

# %%
def pos_features(sentence, i, history): # [_consec-pos-tag-features]
     features = {"suffix(1)": sentence[i][-1:],
                 "suffix(2)": sentence[i][-2:],
                 "suffix(3)": sentence[i][-3:]}
     if i == 0:
         features["prev-word"] = "<START>"
         features["prev-tag"] = "<START>"
     else:
         features["prev-word"] = sentence[i-1]
         features["prev-tag"] = history[i-1]
     return features

class ConsecutivePosTagger(nltk.TaggerI): # [_consec-pos-tagger]

    def __init__(self, train_sents):
        train_set = []
        for tagged_sent in train_sents:
            untagged_sent = nltk.tag.untag(tagged_sent)
            history = []
            for i, (word, tag) in enumerate(tagged_sent):
                featureset = pos_features(untagged_sent, i, history)
                train_set.append( (featureset, tag) )
                history.append(tag)
        self.classifier = nltk.NaiveBayesClassifier.train(train_set)

    def tag(self, sentence):
        history = []
        for i, word in enumerate(sentence):
            featureset = pos_features(sentence, i, history)
            tag = self.classifier.classify(featureset)
            history.append(tag)
        return zip(sentence, history)

# %%
from nltk.corpus import brown
tagged_sents = brown.tagged_sents(categories='news')
size = int(len(tagged_sents) * 0.1)
train_sents, test_sents = tagged_sents[size:], tagged_sents[:size]
tagger = ConsecutivePosTagger(train_sents)
print(tagger.evaluate(test_sents))
# Out:
# 0.798052851182

# %%
posts = nltk.corpus.nps_chat.xml_posts()[:10000]

# %%
def dialogue_act_features(post):
     features = {}
     for word in nltk.word_tokenize(post):
         features['contains({})'.format(word.lower())] = True
     return features

# %%
featuresets = [(dialogue_act_features(post.text), post.get('class'))
                for post in posts]
size = int(len(featuresets) * 0.1)
train_set, test_set = featuresets[size:], featuresets[:size]
classifier = nltk.NaiveBayesClassifier.train(train_set)
print(nltk.classify.accuracy(classifier, test_set))
# Out:
# 0.668
