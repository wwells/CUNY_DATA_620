# %%
import networkx as net
import urllib
import matplotlib.pyplot as plt

% matplotlib inline

# %%
testfile = urllib.URLopener()
testfile.retrieve("https://raw.githubusercontent.com/maksim2042/SNABook/master/chapter3/russians.net", "russians.net")
# Out:
# ('russians.net', <httplib.HTTPMessage instance at 0x7fcd4ab10a28>)

# %%
g=net.read_pajek('russians.net')

# %%
print(net.info(g))
# Out:
# Name: NetworkX
# Type: MultiGraph
# Number of nodes: 87250
# Number of edges: 143120
# Average degree:   3.2807

# %%
deg=net.degree(g)
deg=dict(list(deg))

# %%
deg
# Out:
# {u'svalerievna': 1,
#  u'maly_na': 1,
#  u'koradokosta': 1,
#  u'reinkarni': 2,
#  u'cartoonka': 1,
#  u'prihodi_smotri': 1,
#  u'pocket_girl': 4,
#  u'riendespe': 1,
#  u'musechka': 1,
#  u'chijulia': 1,
#  u'blga': 1,
#  u'gogokostik': 1,
#  u'hieroglyph_elle': 1,
#  u'demettry': 1,
#  u'nata_f_e_ya': 4,
#  u'saburay': 1,
#  u'idealsummer': 1,
#  u'cedov_cergey': 1,
#  u'kharkov_toronto': 1,
#  u'money4you': 6,
#  u'sushka_gim': 1,
#  u'slayerovich': 2,
#  u'azzy_kikoz': 1,
#  u'e_koala': 2,
#  u'indeezzz': 1,
#  u'lyamba': 1,
#  u'fekla13': 1,
#  u'emaslova': 2,
#  u'stepnoy_lis': 1,
#  u'murik_555': 1,
#  u'sonnyk': 2,
#  u'sakura_nu': 2,
#  u'liwingston': 1,
#  u'yuriyk': 2,
#  u'taksus': 1,
#  u'von_tageslicht': 1,
#  u'dionte_zicarel': 1,
#  u'lovesexandmoney': 1,
#  u'span4bob': 1,
#  u'ivar59': 2,
#  u'poupee_russe': 1,
#  u'liana_23b': 1,
#  u'kipriena': 1,
#  u'azuresky2006': 2,
#  u'mary_tudor': 1,
#  u'vivisin': 5,
#  u'zakazfromusa': 1,
#  u'angelita24': 1,
#  u'valja_vorobjoff': 1,
#  u'notolya': 1,
#  u'mr_rrr': 1,
#  u'monsenor': 1,
#  u'xerasse': 1,
#  u'no_lullaby': 1,
#  u'pineki': 1,
#  u'viesel': 1,
#  u'celebs_list': 1,
#  u'novoromantik': 1,
#  u'zaleph': 5,
#  u'zosuspend_mnu': 1,
#  u'ajgul': 2,
#  u'a_nagayna': 1,
#  u'vladimirgin': 4,
#  u'klepacheva': 1,
#  u'luda_berlin': 3,
#  u'p_n_z_8_8': 1,
#  u'darth_bender': 1,
#  u'blackbird_93': 1,
#  u'lernik9491': 1,
#  u'neo_neon': 1,
#  u'andreism': 1,
#  u'xalal4ullag': 3,
#  u'sash13ok': 1,
#  u'_vopros': 1,
#  u'nadeyka_sh': 2,
#  u'mphedoseeva': 2,
#  u'wilmore23': 1,
#  u'zapis_segodny': 2,
#  u'kweenny': 2,
#  u'amalien': 1,
#  u'smuke': 1,
#  u'ffoo': 1,
#  u'274': 1,
#  u'spaccarsi': 4,
#  u'refleksia': 1,
#  u'pani_ga': 1,
#  u'eva_nadu': 1,
#  u'sointransigente': 1,
#  u'designer_plya': 1,
#  u'slivka20': 1,
#  u'humanitarium': 1,
#  u'shakariazia': 2,
#  u'suvorow_': 1,
#  u'ungelt': 2,
#  u'colt_browning': 1,
#  u'adelfofag': 1,
#  u'pawet': 1,
#  u'wild_wild_ash': 1,
#  u'clementine_mil': 2,
#  u'qbeth': 1,
#  u'junmat': 2,
#  u'quarl': 2,
#  u'urd_norman': 1,
#  u'olmeka': 7,
#  u'ehecate': 3,
#  u'verticaltreck': 4,
#  u'amaliaehnsh': 3,
#  u'zanoza_j': 1,
#  u'bumbiere': 3,
#  u'amnuel': 3,
#  u'tat_carera': 1,
#  u'olga_camastra': 2,
#  u'ezhan': 1,
#  u'mgratchyova': 1,
#  u'estlona': 1,
#  u'suntin': 1,
#  u'noizzzefixxxion': 1,
#  u'lakschmi': 1,
#  u'voi_voi': 1,
#  u'yulce': 1,
#  u'negodniki': 1,
#  u'nunya_n': 1,
#  u'zeffiroso': 1,
#  u'leanezoo': 1,
#  u'poshli_nahuy': 1,
#  u'vinta_ks': 1,
#  u'se_mechka': 1,
#  u'kelonjk': 1,
#  u'sunbeam_': 1,
#  u'kidw': 1,
#  u'dorygrey': 2,
#  u'malsinc': 2,
#  u'samadama': 1,
#  u'solvita': 1,
#  u'tulo_spinwolf': 1,
#  u'allenzet': 1,
#  u'vovalcano': 1,
#  u'werton': 1,
#  u'romacha': 1,
#  u'slonikoff_net': 1,
#  u'bisyaka': 1,
#  u'frau_mia': 2,
#  u'v_oktyabre': 1,
#  u'veddma': 2,
#  u'ap_ata': 2,
#  u'dimitri_ts': 1,
#  u'shaulreznik': 9,
#  u'pisankov': 1,
#  u'defrostik': 1,
#  u'alexizm': 2,
#  u'chocolate_tigra': 4,
#  u'elentin': 2,
#  u'adesty': 1,
#  u'catch_': 1,
#  u'shtabss': 3,
#  u'a_n_c_o_r': 1,
#  u'miranduht': 1,
#  u'sterk': 1,
#  u'yanoos': 1,
#  u'battisto': 1,
#  u'launch4you': 1,
#  u'dark_dan': 1,
#  u'pdtplyjcnm': 1,
#  u'fleur_de_cassie': 1,
#  u'kaleidoscope_25': 2,
#  u'tofu_russia': 1,
#  u'anatolyhalizev': 2,
#  u'dilanbim': 2,
#  u'redinteriors': 1,
#  u'positiveonly': 1,
#  u'ur_sun': 2,
#  u'buratilo': 1,
#  u'otto_dracula': 2,
#  u'lolyes': 1,
#  u'alipchik': 2,
#  u'valeks': 2,
#  u'taty528': 1,
#  u'irkku777': 1,
#  u'cannibal': 3,
#  u'rimma_bbusia': 1,
#  u'trequarta': 1,
#  u'dr_divisenko': 1,
#  u'hnyamohnya': 1,
#  u'savenkov': 2,
#  u'kitten_z': 1,
#  u'auth_r': 8,
#  u'goshmarik': 1,
#  u'serapion82': 1,
#  u'koro4ka': 2,
#  u'rustamchik': 1,
#  u'loktev': 1,
#  u'contessa7': 2,
#  u'lusiaparty': 1,
#  u'kuk_ua': 1,
#  u'orechiv': 1,
#  u'coffeetale': 2,
#  u'snorkelstein': 3,
#  u'abeliakov': 1,
#  u'kolenki': 1,
#  u'dvoranord': 4,
#  u'adeelyu': 1,
#  u'nu_ance': 1,
#  u'alternatyva': 1,
#  u'spy_lj': 2,
#  u'punk72': 1,
#  u'aquafea': 2,
#  u'jia_dragon': 1,
#  u'_odinn_': 1,
#  u'turbeeyon': 4,
#  u'borzova_daria': 1,
#  u'kehrmann': 1,
#  u'kenka_lamp': 1,
#  u'crazy_wind': 2,
#  u'wutka': 3,
#  u'nysssya': 1,
#  u'nokino': 1,
#  u'gulnara_maneeva': 1,
#  u'wildcatru': 2,
#  u'theredone': 1,
#  u'lizard__queen': 4,
#  u'artmotion': 2,
#  u'kaizer_tg': 1,
#  u'demographer': 2,
#  u'mulya_diana': 2,
#  u'kletki': 1,
#  u'mari_anna': 2,
#  u'k_stein': 2,
#  u'gourry_aka_pm': 1,
#  u'point_666': 3,
#  u'dazdraperma_k': 2,
#  u'andrelet': 1,
#  u'grassface': 1,
#  u'eva360': 3,
#  u'lucky_delf': 2,
#  u'marizelsu': 1,
#  u'ajojo': 1,
#  u'i_chin': 1,
#  u'yukinochka': 1,
#  u'dmitin': 1,
#  u'forrary': 2,
#  u'_diesel_': 1,
#  u'lonerxxx': 1,
#  u'im_spring': 1,
#  u'mariamz': 4,
#  u'x_style': 1,
#  u'rolliki_com': 1,
#  u'lib_ry': 1,
#  u'olya_lya_': 2,
#  u'i_t': 1,
#  u'jntra': 1,
#  u'ikar_2': 2,
#  u'tasilda': 3,
#  u'daritta': 5,
#  u'absolut_': 1,
#  u'darina29': 1,
#  u'izluchatel': 1,
#  u'lyuniso': 2,
#  u'seioneira': 1,
#  u'mira_a': 1,
#  u'palsmarties': 1,
#  u'fortochka': 8,
#  u'partyofblondes': 1,
#  u'le_haim': 2,
#  u'konsumterra': 1,
#  u'miss_grace': 4,
#  u'delfin_1975': 1,
#  u'lite_lite_lite': 1,
#  u'red_valjok': 1,
#  u'grenzlos': 1,
#  u'_ina_ya_': 1,
#  u'lthdbi': 1,
#  u'tanyastakhanova': 3,
#  u'olwen90': 1,
#  u'swechka': 6,
#  u'gran_aventura': 1,
#  u'medve_ed': 1,
#  u'twilight_g': 1,
#  u'kamenskii': 1,
#  u'yuri_off': 1,
#  u'tom_i_lina': 4,
#  u'dolores_ka': 1,
#  u'otverzhennaia': 1,
#  u'bsng': 1,
#  u'lucky_aka_vera': 1,
#  u'dzokonda': 2,
#  u'anndii': 1,
#  u'_lama': 1,
#  u'belyrabbit': 2,
#  u'pg_bardin': 3,
#  u'ezra_awatara': 1,
#  u'bytmojet': 1,
#  u'anatoliypost': 1,
#  u'hildyulia': 1,
#  u'trunes': 1,
#  u'geenevra': 1,
#  u'lolapokakala': 1,
#  u'svetlaya_lesya': 1,
#  u'lubard_on_line': 1,
#  u'zorraestelar': 1,
#  u'tendress': 1,
#  u'batal0va': 2,
#  u'rabarbar': 1,
#  u'didebuli': 1,
#  u'deodan': 1,
#  u'yusuper': 1,
#  u'sterligov': 2,
#  u'iren_rose': 3,
#  u'hubarevich': 1,
#  u'plucer': 3,
#  u'lady_ester': 1,
#  u'stronge': 1,
#  u'antivit': 2,
#  u'olenka_iv': 1,
#  u'reallaer': 1,
#  u'shakko_kitsune': 2,
#  u'chudonapalochke': 1,
#  u'expert_online': 2,
#  u'star_veselchak': 1,
#  u'cat_ty': 1,
#  u'nashlykid': 1,
#  u'vitaliyshell': 1,
#  u'borzh': 1,
#  u'garciajeans_ukr': 1,
#  u'carpenco': 1,
#  u'epidemiya': 1,
#  u'belleelle': 1,
#  u'gingerella': 5,
#  u'goooseberry': 3,
#  u'tatiana_siver': 1,
#  u'trayma': 1,
#  u'blckwngedroses': 1,
#  u'nattiy': 4,
#  u'nimuravka': 6,
#  u'fif': 14,
#  u'zvezdo4kaman9': 1,
#  u'realya': 1,
#  u'marina_z_s': 2,
#  u'bambookin': 1,
#  u'tsiana': 2,
#  u'alyona_l': 1,
#  u'elena_mihno': 1,
#  u'isida': 1,
#  u'my_sex_dnevnik': 1,
#  u'treatment_child': 1,
#  u'tokuiayasu': 1,
#  u'kapirk': 1,
#  u'13mayapple13': 1,
#  u'cars_drive': 5,
#  u'miayyy': 1,
#  u'insyria': 1,
#  u'scindapsus': 1,
#  u'bublik64': 6,
#  u'le_taxidermiste': 1,
#  u'strizhkov': 1,
#  u'aleks_ter': 2,
#  u'mamkadoctor': 4,
#  u'bnnnnd_spb': 1,
#  u'sova': 2,
#  u'serdcem_i_duwoj': 1,
#  u'edostavka': 2,
#  u'maupiti': 2,
#  u'burtin': 4,
#  u'nt4friends': 1,
#  u'lenavoronova': 1,
#  u'xj_philphil': 1,
#  u'free_emotion': 1,
#  u'kerberusha': 2,
#  u'kurrguzova': 1,
#  u'fasol_bobovay': 1,
#  u'04manska9': 1,
#  u'_bbw': 4,
#  u'spawn_garret': 1,
#  u'_evo': 1,
#  u'ezhi_mil': 1,
#  u'katya_alagich': 3,
#  u'femme_exotique': 1,
#  u'hvostt': 1,
#  u'_superv_': 1,
#  u'donnna_rosa': 2,
#  u'nadorich': 1,
#  u'red_ashberry': 2,
#  u'langusta': 1,
#  u'stopnews_net': 1,
#  u'alevtinamaryina': 2,
#  u'tristana_nata': 1,
#  u'superbody2': 1,
#  u'matv2hoda': 2,
#  u'isya': 1,
#  u'dr_glebson': 1,
#  u'cn_mangetsu': 1,
#  u'mira_shultz': 2,
#  u'vmulder': 1,
#  u'luwyt': 1,
#  u'a5zima': 1,
#  u'na_belka': 1,
#  u'allaq': 3,
#  u'pepsiman6': 1,
#  u'la_cappadocia': 3,
#  u'svvallovv': 1,
#  u'in_dee': 1,
#  u'tabby_ru': 1,
#  u'katrin_84': 1,
#  u'edodolev': 2,
#  u'chekesha': 2,
#  u'thecode': 2,
#  u'avaku': 1,
#  u'avaks': 1,
#  u'und333': 2,
#  u'izubra': 2,
#  u'_snusmumrik': 3,
#  u'rinamari': 2,
#  u'raaddist': 1,
#  u'sol_fasol': 1,
#  u'mazul': 1,
#  u'holly_inna': 1,
#  u'tany_06': 1,
#  u'd_r_i_v_e': 1,
#  u'anna_move': 9,
#  u'belmondodi': 1,
#  u'abramovv': 3,
#  u'stasiaa': 2,
#  u'lake_spirit': 2,
#  u'kozlevski': 2,
#  u'dorenko': 1,
#  u'olga_myakota': 1,
#  u'asyasyai': 4,
#  u'graf_vk': 1,
#  u'natalia1974': 1,
#  u'irishka51254': 1,
#  u'vg36': 2,
#  u'pustota1': 1,
#  u'jinjer_flover': 2,
#  u'serg_stepan': 1,
#  u'valet_k': 1,
#  u'lemur_lori': 5,
#  u'kolzina': 1,
#  u'i_crust': 14,
#  u'penguin_lolo': 1,
#  u'anfisiy': 1,
#  u'loralains': 7,
#  u'tatzay': 1,
#  u'nasekomof': 3,
#  u'chumak2005': 1,
#  u'illeniya': 2,
#  u'ya_puchu_glaz': 1,
#  u'iaugen': 1,
#  u'panda_684': 3,
#  u'slaw_alena': 2,
#  u'ne_prosto_mama': 1,
#  u'mavka_lisova': 2,
#  u'aushedg': 1,
#  u'cosmophoto': 1,
#  u'kris_tall': 3,
#  u'asatokenji': 1,
#  u'brest_stroit': 2,
#  u'tanjas': 1,
#  u'nati_nata': 1,
#  u'tan_go': 2,
#  u'olgatallinn': 1,
#  u'arsbam': 2,
#  u'belorusska': 1,
#  u'ladyganesha': 2,
#  u'greenmara': 2,
#  u'back_in_me': 1,
#  u'vooglooskr': 1,
#  u'deligia': 2,
#  u'nobrow': 2,
#  u'malashka': 4,
#  u'vati_1978': 1,
#  u'palcev': 1,
#  u'cherny_bada': 2,
#  u'deadshadow': 3,
#  u'bridgetjones_ny': 8,
#  u'alex_nik': 1,
#  u'shefchenko': 1,
#  u'saranko': 2,
#  u'avprokofiev': 1,
#  u'your_eithery': 3,
#  u'jannatt': 3,
#  u'superolga': 1,
#  u'anlahel': 1,
#  u'alenochkav': 1,
#  u'kseniapinto': 1,
#  u'morskayaaa': 1,
#  u'alena_stepanova': 1,
#  u'step05': 1,
#  u'vi_1981': 1,
#  u'sa_ba': 2,
#  u'lis_andra': 1,
#  u'azatsh': 1,
#  u'dimka_plotnikov': 1,
#  u'pal_petrovich': 3,
#  u'vgerzane': 1,
#  u'lolly_diva': 4,
#  u'cccameron': 1,
#  u'lightvanilla': 1,
#  u'krem_brulle': 4,
#  u'kvito4ek': 2,
#  u'anetak': 2,
#  u'zloe_tetko': 2,
#  u'dikiy_yojik': 1,
#  u'nurmamed': 1,
#  u'kf4': 1,
#  u'kapelsin': 1,
#  u'ksu_ipekakuana': 1,
#  u'aelita_forget': 1,
#  u'vesnushkacat': 1,
#  u'dieweiseeule': 2,
#  u'a1eksan9ra': 1,
#  u'vladika_fokina': 1,
#  u'_tori_': 2,
#  u'teyli_tei': 1,
#  u'sandrixxx': 2,
#  u'ardesign': 1,
#  u'alexwilf': 1,
#  u'gis_girl': 1,
#  u'xmelnikov': 1,
#  u'alexia_belka': 1,
#  u'godosha': 1,
#  u'foxly': 2,
#  u'011615': 1,
#  u'polmuaddib': 1,
#  u'temik319': 3,
#  u'yarosh_ka': 1,
#  u'expatka': 1,
#  u'musictube_ru': 4,
#  u'ksandr10': 2,
#  u'terricola': 2,
#  u'lunnaya_belka': 2,
#  u'shperk': 2,
#  u'stoit_v_teni': 1,
#  u'tyrichavp': 1,
#  u'achtung_com_ua': 1,
#  u'fuckeach': 1,
#  u'eva_flint': 1,
#  u'sonceniatko': 2,
#  u'agnesmy': 1,
#  u'ingunn_helge': 1,
#  u'open_air_nu': 2,
#  u'pjoter_ivanov': 1,
#  u'rits': 3,
#  u'musikk': 2,
#  u'freedom_consult': 1,
#  u'shaniaxe': 1,
#  u'winston_two': 1,
#  u'lola_lilith': 1,
#  u'xlica27': 2,
#  u'saplady': 1,
#  u'ixci': 1,
#  u'emo_chaos': 1,
#  u'goddamn_russkie': 1,
#  u'lovely_g': 2,
#  u'asja_solnce': 1,
#  u'hsot': 1,
#  u'supremsokol': 1,
#  u'boevoi_zayats': 1,
#  u'deus_quartet': 1,
#  u'diabelek': 8,
#  u'telavivit': 2,
#  u'teatr_vkusa': 1,
#  u'vgo': 1,
#  u'boberrulit': 1,
#  u'in_opposition': 1,
#  u'chimaerandi': 1,
#  u'f1ct1_on': 1,
#  u'soave': 2,
#  u'giraffka': 2,
#  u'bonafiden': 8,
#  u'krasota007': 1,
#  u'talentjr': 1,
#  u'mitek_mitekych': 1,
#  u'zhevtun': 1,
#  u'bip': 5,
#  u'margo_na': 1,
#  u'oprion': 1,
#  u'1satana': 3,
#  u'kriff': 1,
#  u'besheniy67': 1,
#  u'super_novij': 1,
#  u'hot_dognitsa': 1,
#  u'volkar': 1,
#  u'triss_m': 1,
#  u'ohnegrenzen': 1,
#  u'varenik123456': 1,
#  u'denius': 1,
#  u'whitechocolad': 1,
#  u'seo4nik': 1,
#  u'mr_quietest': 8,
#  u'ne_napokaz': 1,
#  u'oxania': 1,
#  u'i_beauty': 1,
#  u'arkady1': 1,
#  u'best_sisters': 2,
#  u'krechetova': 2,
#  u'lc_players': 1,
#  u'deniszheleznyy': 1,
#  u'robinzon_girl': 1,
#  u'elle_belle10': 12,
#  u'yabloki_tybloki': 1,
#  u'argentea_ya': 1,
#  u'mkoenig': 2,
#  u'sexonly': 1,
#  u'dzetta': 3,
#  u'quaeritans': 1,
#  u'radegost': 2,
#  u'dj_ladydisco': 1,
#  u'garret_lab': 1,
#  u'barolya': 1,
#  u'gazirovannaja': 3,
#  u'0ffline': 1,
#  u'mellot': 1,
#  u'poma': 4,
#  u'sibeira': 1,
#  u'charunga': 1,
#  u'uqbar': 2,
#  u'droanton': 1,
#  u'krestiknolik': 1,
#  u'credo_always': 1,
#  u'joe_chasmtons': 2,
#  u'kroshka_enot_': 6,
#  u'yellow_rat': 3,
#  u'miau_marusya': 1,
#  u'alfalfalfa': 1,
#  u'inmymind_kirill': 1,
#  u'ar_asti': 1,
#  u'lenochka11': 1,
#  u'matilda_ussr': 1,
#  u'ann_orlova': 1,
#  u'vechnaia_zima': 1,
#  u'otello': 1,
#  u'crimblecromble': 2,
#  u'varvarra': 3,
#  u'mobis33': 1,
#  u'kumiko_artistka': 1,
#  u'domkratov': 1,
#  u'temptee': 4,
#  u'mikeg_99': 2,
#  u'deatravel': 1,
#  u'i_n_n': 2,
#  u'simcha_eichel': 1,
#  u'ala_guerre': 2,
#  u'likeladygodiva': 1,
#  u'tanyat': 1,
#  u'korolka': 2,
#  u'irena_iris': 4,
#  u'orleanz': 4,
#  u'zzubr': 1,
#  u'indig0z': 3,
#  u'gainarain': 1,
#  u'alindra': 1,
#  u'cnayhuto': 1,
#  u'tigra_katy': 2,
#  u'rock_f': 1,
#  u'dushegubik': 1,
#  u'shpion14': 1,
#  u'radostev_v': 1,
#  u'moerta': 2,
#  u'veryloving': 1,
#  u'bulfriend': 3,
#  u'_shpulka': 4,
#  u'elena_biber': 2,
#  u'upiachka': 1,
#  u'_tankist': 1,
#  u'marineval': 1,
#  u'okhalatnikova': 1,
#  u'ajushka': 1,
#  u'stobla': 1,
#  u'xujasse': 1,
#  u'shtykh': 1,
#  u'zapitaya': 4,
#  u'stichelmeister': 2,
#  u'young_pickup': 1,
#  u'anirinka': 7,
#  u'polit_mudak': 1,
#  u'6atenka': 1,
#  u'teplitskaya_mod': 1,
#  u'puchs': 1,
#  u'towerkeeper': 1,
#  u'monusya': 1,
#  u'twaneq': 1,
#  u'f_lia': 1,
#  u'peggy_s': 4,
#  u'zverenush': 1,
#  u'arctickfox1911': 1,
#  u'carmmen': 1,
#  u'avotiya': 3,
#  u'flying_bee2': 1,
#  u'clips_': 1,
#  u'maxteror': 1,
#  u'mclaren2000': 1,
#  u'ys_pumpui': 1,
#  u'pampulus': 4,
#  u'kizhajla': 1,
#  u'thebestya': 3,
#  u'konoza': 1,
#  u'elbonia': 4,
#  u'madamchic': 1,
#  u'holy_lunacy': 1,
#  u'de_kor': 1,
#  u'sentfromupabove': 2,
#  u'igor_mkrt': 12,
#  u'cheshire_pig': 7,
#  u'kucha_mala': 7,
#  u'minimum_riska': 1,
#  u'nishtyak': 1,
#  u'nadiki': 1,
#  u'its_funky': 1,
#  u'apo_monitor': 1,
#  u'moon_abbys': 1,
#  u'_gromova_': 1,
#  u'trivee': 1,
#  u'webdevel': 1,
#  u'twix7681': 1,
#  u'immoralist': 26,
#  u'n0vikova': 3,
#  u'charliesies': 3,
#  u'zelda_cat': 1,
#  u'tolstiy': 2,
#  u'marianner': 1,
#  u'lavictoria': 1,
#  u'ponka_kiev': 1,
#  u'diyara': 1,
#  u'gladworld': 2,
#  u'starayakniga': 3,
#  u'molodoy_4emodan': 3,
#  u'wowwife': 1,
#  u'iry': 2,
#  u'mikeorl': 4,
#  u'oldbore': 1,
#  u'lenusch11': 2,
#  u'freeraser': 1,
#  u'irr': 2,
#  u'no_speech': 2,
#  u'djechka_vorobei': 1,
#  u'posovetui': 2,
#  u'segodnya': 4,
#  u'laoshe': 2,
#  u'akm_akm': 1,
#  u'hina_chleck': 1,
#  u'esfrodl': 2,
#  u'x_polkovnik': 1,
#  u'jinjerd': 3,
#  u'violin_fox': 1,
#  u'f_developer': 1,
#  u'panthure': 2,
#  u'shelter_a': 1,
#  u'koza_nostra': 1,
#  u'ane4ka_zajc': 1,
#  u'zubnik_fabrique': 1,
#  u'rttv': 1,
#  u'zajchevskij': 1,
#  u'candelila': 1,
#  u'borschhh': 1,
#  u'klotti': 2,
#  u'capuchin_ka': 1,
#  u'squo': 1,
#  u'sun_day': 1,
#  u'munakokkelli': 1,
#  u'oui_cannelle': 1,
#  u'almira2005': 947,
#  u'nikesha': 1,
#  u'ggmarketing': 1,
#  u'paparachi': 1,
#  u'mina_und_otto': 1,
#  u'loftetagi': 1,
#  u'nob239': 1,
#  u'babulja': 1,
#  u'lucysd': 1,
#  u'm_ul_s': 1,
#  u'winniepooh_i_k': 3,
#  u'soljarka': 1,
#  u'a_4_ia': 1,
#  u'natasha_kob': 1,
#  u'lukerija': 1,
#  u'lark_dis': 2,
#  u'a_bl': 1,
#  u'moravit': 1,
#  u'denisuy': 1,
#  u'u_l_i_n_k_a': 2,
#  u'vuzya': 1,
#  u'miss_4erry': 1,
#  u'ce_man': 1,
#  u'chelovek': 1,
#  u'kino_bez_graniz': 1,
#  u'la_lezarde': 3,
#  u'n013e': 2,
#  u'its_ma_life': 1,
#  u'garfield_y': 5,
#  u'karrykarry': 1,
#  u'bod_hi': 1,
#  u'dzyubochka': 2,
#  u'yahoo_zloi': 1,
#  u'nettless': 3,
#  u'organs_pusher': 2,
#  u'garfield_s': 3,
#  u'x_line': 1,
#  u'vasi_lisa': 1,
#  u'furzicle': 1,
#  u'izummmm': 2,
#  u'vlodamir': 1,
#  u'new_azzia': 1,
#  u'devushka_mechty': 1,
#  u'lledanni': 3,
#  u'mmontecarlo': 1,
#  u'basque': 3,
#  u'deferre': 6,
#  u'grimmy3d': 1,
#  u'ice_nugget': 1,
#  u'yuliaskrap': 1,
#  u'odri_hepbern': 1,
#  u'onikuz': 1,
#  u'dimqa': 1,
#  u'totsvet': 2,
#  u'voblic': 3,
#  u'white_ashes_13': 1,
#  u'leelasf': 1,
#  u'a_galaxy': 2,
#  u'olejnik': 6,
#  u'lana_kou': 3,
#  u'frr': 2,
#  u'visnushko': 1,
#  u'noger_vruker': 1,
#  u'detenish': 4,
#  u'art_gudkof': 1,
#  u'shlyahtich': 4,
#  u'naife': 1,
#  u'__cara__': 1,
#  u'vi_laschenov': 1,
#  u'kvakshi': 4,
#  u'_sone4ka': 1,
#  u'regul': 2,
#  u'wwwnastenawww': 1,
#  u'mahaon_ysh': 1,
#  u'ryzhaya_zluchka': 2,
#  u'ivkoshkin': 1,
#  u'perlovka_blog': 2,
#  u'janataha': 2,
#  u'kondratti': 2,
#  u'masam_3': 1,
#  u'kala_hansa': 1,
#  u'busyana': 1,
#  u'jeol': 7,
#  u'tazmaniand_evil': 1,
#  u'novi_9': 2,
#  u'rina_grant': 1,
#  u'lomenille': 1,
#  u'sergei_anufriev': 1,
#  u'string_fever': 1,
#  u'zvetok_sakuri': 1,
#  u'brilly23': 1,
#  u'molcaxitl': 1,
#  u'kikimora_b': 6,
#  u'azbonfad': 1,
#  u'zakata': 3,
#  u'inessa_b': 4,
#  u'intaf': 3,
#  u'assolata': 2,
#  u'nattiko': 1,
#  u'eto_ne_ona': 1,
#  u'm_paramonov': 1,
#  u'vitbel2000': 1,
#  u'nadejda_ivanova': 1,
#  u'damirs': 1,
#  u'hydrargirum': 1,
#  u'reshetnikoff2': 1,
#  u'3lobotryasov': 1,
#  u'sschfdrz': 3,
#  u'inessa_v': 3,
#  u'a_vysotskiy': 1,
#  u'rmorga': 1,
#  u'nasuto_procione': 1,
#  u'shupaka': 2,
#  u'zalmax': 2,
#  u'builtforcomfort': 1,
#  u'willy_sever': 1,
#  u'mfermin': 1,
#  u'shutov_sparkle': 2,
#  u'arhangelsky': 1,
#  u'gobuz': 2,
#  u'ssolaa': 5,
#  u'mother_jones': 2,
#  u'swiss_wife': 2,
#  u'mishka_kaola': 2,
#  u'san4a': 1,
#  u'doctorbrunja': 1,
#  u'all_abaut': 2,
#  u'n_e': 1,
#  u'igornem': 1,
#  u'anaeill_nitting': 1,
#  u'foshizd': 1,
#  u'oygenn': 1,
#  u'err0r_404': 2,
#  u'sandeys': 1,
#  u'principall': 1,
#  u'milewska': 1,
#  u'ice_skws': 1,
#  u'tejido': 1,
#  u'discreet_chaos': 1,
#  u'loushu': 2,
#  u'djtonik': 1,
#  u'zench': 2,
#  u'yellowsmoke1': 2,
#  u'scaramel': 1,
#  u'andrushka_il': 4,
#  u'valenok8': 1,
#  u'gl_notes': 1,
#  u'n_a_d_i': 1,
#  u'loandr': 1,
#  u'krootee': 1,
#  u'l_ek_a': 1,
#  u'devochk0': 1,
#  u'true_sergio': 1,
#  u'fiquet': 1,
#  u'chek_100': 3,
#  u'zhukola': 1,
#  u'guruken': 1,
#  u'ph_b': 4,
#  u'baby_malishka': 1,
#  u'mm_jam': 2,
#  u'81les': 1,
#  u'0l0': 3,
#  u'socialism_vk': 2,
#  u'boziya_korovka': 1,
#  u'bazjak': 1,
#  u'georgich': 1,
#  u'i_marka': 1,
#  u'v_olga_dnepr': 2,
#  u'chidora': 1,
#  u'gorbarsky': 1,
#  u'morgulis': 4,
#  u'elfen_bride': 1,
#  u'lepeztok': 2,
#  u'liilaa': 2,
#  u'solga77': 2,
#  u'segan89': 1,
#  u'katsik': 3,
#  u'mashaeihen': 1,
#  u'shuvovse': 8,
#  u'noblewoman': 2,
#  u'el_kat': 1,
#  u'shining_drop': 1,
#  u'kreolan': 3,
#  u'f_lynx': 1,
#  u'ksjuh': 3,
#  u'nikitina_mama': 2,
#  u'krylovilya': 1,
#  u'lady_catarina': 1,
#  u'okwind': 1,
#  u'drbashlachev': 1,
#  u'ortivika': 407,
#  u'glukagain': 1,
#  u'hans_zivers': 1,
#  u'tsisar': 4,
#  u'glebfedin': 3,
#  u'mona81': 2,
#  u'prometa': 4,
#  u'masterlab': 1,
#  u'kaidenceex': 1,
#  u'sicvom': 1,
#  u'elkur': 1,
#  u'lar_uss': 2,
#  u'jimbolaya': 1,
#  u'stnn': 4,
#  u'stnk': 2,
#  u'eos_ta': 1,
#  u'ksurrrealizm': 1,
#  u'morestry': 1,
#  u'0_stranger': 1,
#  u'anirik_01': 1,
#  u'nostalgie_ee': 4,
#  u'algira': 1,
#  u'my_za': 1,
#  u'gelmasha': 2,
#  u'gleolite': 3,
#  u'feofan79': 2,
#  u'scheslvit': 1,
#  u'fatcomposer': 1,
#  u'elena_kiev': 1,
#  u'chanush': 2,
#  u'hotshkin': 1,
#  u'aplastinin': 1,
#  u'prosto_tosha': 2,
#  u'adelja': 1,
#  u'rediska_2': 1,
#  u'you93': 1,
#  u'lipovetc': 1,
#  u'kapara2005': 2,
#  u'trans20006': 2,
#  u'vrazilo': 1,
#  u'bibigosha': 4,
#  u'dovshalom': 1,
#  u'lpberia': 1,
#  u'lchak': 2,
#  u'dawnetak': 1,
#  u'tai_tay': 2,
#  u'kloodj': 1,
#  u'prosto_ya_n': 2,
#  u'ksenia': 2,
#  u'koz_a_la_nues': 2,
#  u'dedran': 7,
#  ...}

# %%
deg['valerois']
# Out:
# 232

# %%
def sorted_map(map):
    ms = sorted(map.iteritems(), key=lambda(k,v): (-v,k))
    return ms

# %%
ds=sorted_map(deg)
ds[0:9]
# Out:
# [(u'borisakunin', 4691),
#  (u'doctor_liza', 3046),
#  (u'tareeva', 2970),
#  (u'cheger', 2887),
#  (u'karial', 2717),
#  (u'snorapp', 2707),
#  (u'masha_koroleva', 2683),
#  (u'elladkin', 2616),
#  (u'samoleg', 2597)]

# %%
print net.number_of_nodes(g)
print net.number_of_edges(g)
# Out:
# 87250
# 143120

# %%
#eigenvector_centrality(g)
